# %%
# !pip install lightautoml -q
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.0/399.0 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.0/216.0 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 96.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.9 MB/s eta 0:00:00
#   Building wheel for json2html (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.

# %%
import gc
import os
from collections import defaultdict
from pathlib import Path

import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from lightautoml.automl.presets.tabular_presets import (TabularAutoML,
                                                        TabularUtilizedAutoML)
from lightautoml.report.report_deco import ReportDeco
from lightautoml.tasks import Task
from sklearn.metrics import auc, precision_recall_curve
from sklearn.model_selection import (GroupKFold, GroupShuffleSplit,
                                     StratifiedGroupKFold)
from tqdm.notebook import tqdm

# %%
MAIN_PATH = 'avito-train-combined/data/avito-merged-dataset/'
ECOM_PRETRAIN = 'avito-train-combined/data/clip-marqofashionsiglip-marqoecom-top2kaggle/'
RESNET_PATH = 'avito-train-combined/data/resnet-cossim/'
KAGGLE_TOP5 = 'avito-train-combined/data/top5-kaggle/'
BERTA_PATH = 'avito-train-combined/data/berta-pretrained-cossims/'
RUBERT_TINY_OOF_PATH = 'avito-train-combined/data/rubert-folds/'
RUBERT_TINY_PREDS_PATH = 'avito-train-combined/data/rubert-test-preds/'
E5LARGE_OOF_PATH = 'avito-train-combined/data/avito-e5-large-pretrain/'
E5LARGE_PREDS_PATH = 'avito-train-combined/data/avito-e5-large-test/'
REV_RUBERT_TINY_OOF_PATH = 'avito-train-combined/data/name_desc_bert_oof_rev/'
REV_RUBERT_TINY_PREDS_PATH = 'avito-train-combined/data/name-desc-bert-preds-rev/'
USERBGE_COSSIMS_PATH = 'avito-train-combined/data/userbge-cossims/'
RUBERT_BASE_TEST_PREDS_PATH = 'avito-train-combined/data/rubert-fixed-test-preds/'
RUBERT_BASE_TEST_PREDS_REV_PATH = 'avito-train-combined/data/rubert-fixed-test-preds-rev/'
FT_PREDS_PATH = 'avito-train-combined/data/ft-preds2/'
RUBERT_BASE_OOF_PATH = 'avito-train-combined/data/trained-rubert-base-preds/'
RUBERT_BASE_OOF_REV_PATH = 'avito-train-combined/data/trained-rubert-base-preds-rev/'
ROUGE_PATH = 'rouge-avito/'

USE_MEAN_BASE_AND_REV = False

# %%
train = pd.read_parquet(MAIN_PATH + 'train_df.parquet')
test = pd.read_parquet(MAIN_PATH + 'test_df.parquet')

# %%
to_drop = [
    'category_level_1_1', 'category_level_1_2',
    'category_level_2_1', 'category_level_2_2',
    'category_level_3_1', 'category_level_3_2',
    'category_level_4_1', 'category_level_4_2',
]

train[to_drop] = train[to_drop].fillna('none')

train['unique_cat_1'] = train['category_level_1_1'] + '_' + train['category_level_1_2']
train['unique_cat_2'] = train['category_level_2_1'] + '_' + train['category_level_2_2']
train['unique_cat_3'] = train['category_level_3_1'] + '_' + train['category_level_3_2']
train['unique_cat_4'] = train['category_level_4_1'] + '_' + train['category_level_4_2']

test[to_drop] = test[to_drop].fillna('none')

test['unique_cat_1'] = test['category_level_1_1'] + '_' + test['category_level_1_2']
test['unique_cat_2'] = test['category_level_2_1'] + '_' + test['category_level_2_2']
test['unique_cat_3'] = test['category_level_3_1'] + '_' + test['category_level_3_2']
test['unique_cat_4'] = test['category_level_4_1'] + '_' + test['category_level_4_2']

train.drop(columns=to_drop, axis=1, inplace=True)
gc.collect()

test.drop(columns=to_drop, axis=1, inplace=True)
gc.collect()
# Out:
# 0

# %%
numerical_features = train.select_dtypes(
    include=['float16', 'float32', 'float64', 'int8', 'int16', 'int32', 'int64']
).columns.to_list()

cols_with_inf = train[numerical_features].columns[np.isinf(train[numerical_features]).any()].tolist()

print("Колонки с inf:", cols_with_inf)

train.replace([np.inf, -np.inf], np.nan, inplace=True)
test.replace([np.inf, -np.inf], np.nan, inplace=True)
# Out:
# Колонки с inf: ['name_tanimoto', 'name_norm_tanimoto', 'name_en_tanimoto', 'name_mix_tanimoto', 'description_en_tanimoto', 'description_mix_tanimoto', 'name_tokens_w_digits_tanimoto', 'description_tokens_w_digits_tanimoto']

# %%
cat_features = [
    'is_same_location',
    'is_same_region',
    'category_level_1_match',
    'category_level_2_match',
    'category_level_3_match',
    'category_level_4_match',
    'category_level_3_fillness',
    'category_level_4_fillness',
    'n_images_fillness',
    'unique_cat_1',
    'unique_cat_2',
    'unique_cat_3',
    'unique_cat_4',
]

train[cat_features] = train[cat_features].astype(str)
test[cat_features] = test[cat_features].astype(str)

# %%
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                    gc.collect()
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                    gc.collect()
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                    gc.collect()
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
                    gc.collect()
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                    gc.collect()
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                    gc.collect()
                else:
                    df[col] = df[col].astype(np.float64)
                    gc.collect()
        else:
            if df[col].nunique() == 2:
                df[col] = df[col].astype('bool')
            gc.collect()

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    gc.collect()
    
    return df

# %%
train = reduce_mem_usage(train)
# Out:
# Memory usage of dataframe is 6546.15 MB
# Memory usage after optimization is: 1803.24 MB
# Decreased by 72.5%

# %%
test = reduce_mem_usage(test)
# Out:
# Memory usage of dataframe is 1741.41 MB
# Memory usage after optimization is: 472.55 MB
# Decreased by 72.9%

# %%
train = train.sort_values(by=['variantid_1', 'variantid_2'])
test = test.sort_values(by=['variantid_1', 'variantid_2'])

# %%
# --- IMG FEATURES ---

# pretrain clip
train_clip = pd.read_parquet(ECOM_PRETRAIN + 'cossim_final_embeddings_train_CLIP.parquet')
test_clip = pd.read_parquet(ECOM_PRETRAIN + 'cossim_final_embeddings_test_CLIP.parquet')

train_clip = train_clip.sort_values(by=['variantid_1', 'variantid_2'])
test_clip = test_clip.sort_values(by=['variantid_1', 'variantid_2'])
train['clip_cosine_sim'] = train_clip['cosine_sim']
test['clip_cosine_sim'] = test_clip['cosine_sim']
del train_clip, test_clip

# pretrain fashion siglip
train_fashionsiglip = pd.read_parquet(ECOM_PRETRAIN + 'cossim_final_embeddings_fashion_clip_train.parquet')
test_fashionsiglip = pd.read_parquet(ECOM_PRETRAIN + 'cossim_final_embeddings_fashion_clip_test.parquet')

train_fashionsiglip = train_fashionsiglip.sort_values(by=['variantid_1', 'variantid_2'])
test_fashionsiglip = test_fashionsiglip.sort_values(by=['variantid_1', 'variantid_2'])
train['fashionsiglip_cosine_sim'] = train_fashionsiglip['cosine_sim']
test['fashionsiglip_cosine_sim'] = test_fashionsiglip['cosine_sim']
del train_fashionsiglip, test_fashionsiglip

# pretrain marqo ecom
train_ecom = pd.read_parquet(ECOM_PRETRAIN + 'cossim_final_embeddings_ecomm_train.parquet')
test_ecom = pd.read_parquet(ECOM_PRETRAIN + 'cossim_final_embeddings_ecomm_test.parquet')

train_ecom = train_ecom.sort_values(by=['variantid_1', 'variantid_2'])
test_ecom = test_ecom.sort_values(by=['variantid_1', 'variantid_2'])
train['ecom_cosine_sim'] = train_ecom['cosine_sim']
test['ecom_cosine_sim'] = test_ecom['cosine_sim']
del train_ecom, test_ecom

# kaggle top2 model, bugged
# train_top2kaggle = pd.read_parquet(ECOM_PRETRAIN + 'cossim_final_top2_kaggle_train.parquet')
# test_top2kaggle = pd.read_parquet(ECOM_PRETRAIN + 'cossim_final_top2_kaggle_test.parquet')

# train_top2kaggle = train_top2kaggle.sort_values(by=['variantid_1', 'variantid_2'])
# test_top2kaggle = test_top2kaggle.sort_values(by=['variantid_1', 'variantid_2'])
# train['top2kaggle_cosine_sim'] = train_top2kaggle['cosine_sim']
# test['top2kaggle_cosine_sim'] = test_top2kaggle['cosine_sim']
# del train_top2kaggle, test_top2kaggle

# kaggle top5 model
train_top5kaggle = pd.read_parquet(KAGGLE_TOP5 + 'cossim_final_concat_train.parquet')
test_top5kaggle = pd.read_parquet(KAGGLE_TOP5 + 'cossim_final_concat_test.parquet')

train_top5kaggle = train_top5kaggle.sort_values(by=['variantid_1', 'variantid_2'])
test_top5kaggle = test_top5kaggle.sort_values(by=['variantid_1', 'variantid_2'])
train['top5kaggle_cosine_sim'] = train_top5kaggle['cosine_sim']
test['top5kaggle_cosine_sim'] = test_top5kaggle['cosine_sim']
del train_top5kaggle, test_top5kaggle

# trained resnet
train_resnet = pd.read_parquet(RESNET_PATH + 'train_resnet_cossim.parquet')
test_resnet = pd.read_parquet(RESNET_PATH + 'test_resnet_cossim.parquet')

train_resnet = train_resnet.sort_values(by=['variantid_1', 'variantid_2']).reset_index(drop=True)
test_resnet = test_resnet.sort_values(by=['variantid_1', 'variantid_2']).reset_index(drop=True)
train['resnet_cosine_sim'] = train_resnet['cossims_resnet']
test['resnet_cosine_sim'] = test_resnet['cossims_resnet']
del train_resnet, test_resnet

gc.collect()

# --- TEXT FEATURES ---

# pretrain berta
berta_cossims_train_part1 = pd.read_parquet(BERTA_PATH + 'berta_cossims_train_part1.parquet')
berta_cossims_train_part2 = pd.read_parquet(BERTA_PATH + 'berta_cossims_train_part2.parquet')
berta_cossims_train = pd.concat([berta_cossims_train_part1, berta_cossims_train_part2])
berta_cossims_test = pd.read_parquet(BERTA_PATH + 'berta_cossims_test.parquet')

berta_cossims_train = berta_cossims_train.sort_values(by=['variantid_1', 'variantid_2'])
berta_cossims_test = berta_cossims_test.sort_values(by=['variantid_1', 'variantid_2'])
train['berta_cossim'] = berta_cossims_train['berta_cossim']
test['berta_cossim'] = berta_cossims_test['berta_cossim']

del berta_cossims_train_part1, berta_cossims_train_part2, berta_cossims_train, berta_cossims_test
gc.collect()

# trained rubert (cherez zhopu rukamu obuchen)
rubert_oof_fold0 = pd.read_parquet(RUBERT_TINY_OOF_PATH + 'name_desc_bert_fold0.parquet')
rubert_oof_fold1 = pd.read_parquet(RUBERT_TINY_OOF_PATH + 'name_desc_bert_fold1.parquet')
rubert_oof_fold2 = pd.read_parquet(RUBERT_TINY_OOF_PATH + 'name_desc_bert_fold2.parquet')
rubert_oof_fold3 = pd.read_parquet(RUBERT_TINY_OOF_PATH + 'name_desc_bert_fold3.parquet')
rubert_oof_fold4 = pd.read_parquet(RUBERT_TINY_OOF_PATH + 'name_desc_bert_fold4.parquet')

rubert_test_pred_fold0 = pd.read_parquet(RUBERT_TINY_PREDS_PATH + 'name_desc_rubert_tiny_turbo_2048_wce_0.parquet')
rubert_test_pred_fold1 = pd.read_parquet(RUBERT_TINY_PREDS_PATH + 'name_desc_rubert_tiny_turbo_2048_wce_1.parquet')
rubert_test_pred_fold2 = pd.read_parquet(RUBERT_TINY_PREDS_PATH + 'name_desc_rubert_tiny_turbo_2048_wce_2.parquet')
rubert_test_pred_fold3 = pd.read_parquet(RUBERT_TINY_PREDS_PATH + 'name_desc_rubert_tiny_turbo_2048_wce_3.parquet')
rubert_test_pred_fold4 = pd.read_parquet(RUBERT_TINY_PREDS_PATH + 'name_desc_rubert_tiny_turbo_2048_wce_4.parquet')

rubert_oof_fold0.rename(columns={'name_desc_bert_oof1': 'name_desc_rubert_tiny_turbo_2048_wce'}, inplace=True)
rubert_oof_fold1.rename(columns={'name_desc_bert_oof4': 'name_desc_rubert_tiny_turbo_2048_wce'}, inplace=True)
rubert_oof_fold2.rename(columns={'name_desc_bert_oof4': 'name_desc_rubert_tiny_turbo_2048_wce'}, inplace=True)
rubert_oof_fold3.rename(columns={'name_desc_bert_oof4': 'name_desc_rubert_tiny_turbo_2048_wce'}, inplace=True)
rubert_oof_fold4.rename(columns={'name_desc_bert_oof4': 'name_desc_rubert_tiny_turbo_2048_wce'}, inplace=True)

rubert_oof_fold0 = rubert_oof_fold0.sort_values(by=['variantid_1', 'variantid_2'])
rubert_oof_fold1 = rubert_oof_fold1.sort_values(by=['variantid_1', 'variantid_2'])
rubert_oof_fold2 = rubert_oof_fold2.sort_values(by=['variantid_1', 'variantid_2'])
rubert_oof_fold3 = rubert_oof_fold3.sort_values(by=['variantid_1', 'variantid_2'])
rubert_oof_fold4 = rubert_oof_fold4.sort_values(by=['variantid_1', 'variantid_2'])

rubert_oof = rubert_oof_fold0['name_desc_rubert_tiny_turbo_2048_wce'] + rubert_oof_fold1['name_desc_rubert_tiny_turbo_2048_wce'] + rubert_oof_fold2['name_desc_rubert_tiny_turbo_2048_wce'] + rubert_oof_fold3['name_desc_rubert_tiny_turbo_2048_wce'] + rubert_oof_fold4['name_desc_rubert_tiny_turbo_2048_wce']

rubert_test_pred_fold0 = rubert_test_pred_fold0.sort_values(by=['variantid_1', 'variantid_2'])
rubert_test_pred_fold1 = rubert_test_pred_fold1.sort_values(by=['variantid_1', 'variantid_2'])
rubert_test_pred_fold2 = rubert_test_pred_fold2.sort_values(by=['variantid_1', 'variantid_2'])
rubert_test_pred_fold3 = rubert_test_pred_fold3.sort_values(by=['variantid_1', 'variantid_2'])
rubert_test_pred_fold4 = rubert_test_pred_fold4.sort_values(by=['variantid_1', 'variantid_2'])

rubert_preds = (rubert_test_pred_fold0['name_desc_rubert_tiny_turbo_2048_wce_0'] + rubert_test_pred_fold1['name_desc_rubert_tiny_turbo_2048_wce_1'] + rubert_test_pred_fold2['name_desc_rubert_tiny_turbo_2048_wce_2'] + rubert_test_pred_fold3['name_desc_rubert_tiny_turbo_2048_wce_3'] + rubert_test_pred_fold4['name_desc_rubert_tiny_turbo_2048_wce_4']) / 5

train['name_desc_rubert_tiny_turbo_2048_wce'] = rubert_oof
test['name_desc_rubert_tiny_turbo_2048_wce'] = rubert_preds

del rubert_oof_fold0, rubert_oof_fold1, rubert_oof_fold2, rubert_oof_fold3, rubert_oof_fold4
del rubert_oof
del rubert_test_pred_fold0, rubert_test_pred_fold1, rubert_test_pred_fold2, rubert_test_pred_fold3, rubert_test_pred_fold4
del rubert_preds
gc.collect()

# pretrain e5large
e5large_cossims_train_part1 = pd.read_parquet(E5LARGE_OOF_PATH + 'e5large_cossims_fold0.parquet')
e5large_cossims_train_part2 = pd.read_parquet(E5LARGE_OOF_PATH + 'e5large_cossims_fold1.parquet')
e5large_cossims_train_part3 = pd.read_parquet(E5LARGE_OOF_PATH + 'e5large_cossims_fold2.parquet')
e5large_cossims_train_part4 = pd.read_parquet(E5LARGE_OOF_PATH + 'e5large_cossims_fold3.parquet')
e5large_cossims_train_part5 = pd.read_parquet(E5LARGE_OOF_PATH + 'e5large_cossims_fold4.parquet')

e5large_cossims_train = pd.concat([
    e5large_cossims_train_part1,
    e5large_cossims_train_part2,
    e5large_cossims_train_part3,
    e5large_cossims_train_part4,
    e5large_cossims_train_part5
])
e5large_cossims_train = e5large_cossims_train.sort_values(by=['variantid_1', 'variantid_2'])

del e5large_cossims_train_part1, e5large_cossims_train_part2, e5large_cossims_train_part3, e5large_cossims_train_part4, e5large_cossims_train_part5
gc.collect()

e5large_cossims_test_part1 = pd.read_parquet(E5LARGE_PREDS_PATH + 'e5large_cossims_part1.parquet')
e5large_cossims_test_part2 = pd.read_parquet(E5LARGE_PREDS_PATH + 'e5large_cossims_part2.parquet')

e5large_cossims_test = pd.concat([
    e5large_cossims_test_part1,
    e5large_cossims_test_part2,
])
e5large_cossims_test = e5large_cossims_test.sort_values(by=['variantid_1', 'variantid_2'])

del e5large_cossims_test_part1, e5large_cossims_test_part2
gc.collect()

train['e5large_cossim'] = e5large_cossims_train['e5large_cossim']
test['e5large_cossim'] = e5large_cossims_test['e5large_cossim']

del e5large_cossims_train, e5large_cossims_test
gc.collect()

# rev trained rubert (cherez zhopu rukamu obuchen)
rubert_oof_rev = pd.read_parquet(REV_RUBERT_TINY_OOF_PATH + 'name_desc_bert_oof_rev.parquet')
rubert_preds_rev = pd.read_parquet(REV_RUBERT_TINY_PREDS_PATH + 'name_desc_bert_preds_rev.parquet')

rubert_oof_rev = rubert_oof_rev.sort_values(by=['variantid_1', 'variantid_2'])
rubert_preds_rev = rubert_preds_rev.sort_values(by=['variantid_1', 'variantid_2'])
train['name_desc_rubert_tiny_turbo_2048_wce_rev'] = rubert_oof_rev['name_desc_bert_oof_rev']
test['name_desc_rubert_tiny_turbo_2048_wce_rev'] = rubert_preds_rev['name_desc_bert_preds_rev']
del rubert_oof_rev, rubert_preds_rev

gc.collect()

# rubert tta
if USE_MEAN_BASE_AND_REV:
    train['name_desc_rubert_tiny_turbo_2048_wce_tta'] = (train['name_desc_rubert_tiny_turbo_2048_wce'] + train['name_desc_rubert_tiny_turbo_2048_wce_rev']) / 2
    test['name_desc_rubert_tiny_turbo_2048_wce_tta'] = (test['name_desc_rubert_tiny_turbo_2048_wce'] + test['name_desc_rubert_tiny_turbo_2048_wce_rev']) / 2
    del train['name_desc_rubert_tiny_turbo_2048_wce'], train['name_desc_rubert_tiny_turbo_2048_wce_rev']
    del test['name_desc_rubert_tiny_turbo_2048_wce'], test['name_desc_rubert_tiny_turbo_2048_wce_rev']
    gc.collect()

# pretrain userbge
userbge_cossims_train = pd.DataFrame()
userbge_cossims_test = pd.DataFrame()

for i in range(1, 16):
    curr_df = pd.read_parquet(USERBGE_COSSIMS_PATH + f'userbge_cossims_train_part{i}.parquet')
    userbge_cossims_train = pd.concat([userbge_cossims_train, curr_df])
    print(f'{userbge_cossims_train.shape=}')
userbge_cossims_train = userbge_cossims_train.sort_values(by=['variantid_1', 'variantid_2'])

for i in range(1, 5):
    curr_df = pd.read_parquet(USERBGE_COSSIMS_PATH + f'/userbge_cossims_test_part{i}.parquet')
    userbge_cossims_test = pd.concat([userbge_cossims_test, curr_df])
    print(f'{userbge_cossims_test.shape=}')
userbge_cossims_test = userbge_cossims_test.sort_values(by=['variantid_1', 'variantid_2'])

del curr_df
gc.collect()

train['userbge_cossim'] = userbge_cossims_train['userbge_cossim']
test['userbge_cossim'] = userbge_cossims_test['userbge_cossim']

del userbge_cossims_train, userbge_cossims_test
gc.collect()

# --- тут именно до сэмпла! ---

# trained rubert-base test preds
rubert_base_pred = pd.read_csv(
    RUBERT_BASE_TEST_PREDS_PATH + 'rubert_ZAEBAL_SUKA.csv'
).rename(columns={'base_id': 'variantid_1', 'cand_id': 'variantid_2'})
rubert_base_pred = rubert_base_pred.sort_values(by=['variantid_1', 'variantid_2']).reset_index(drop=True)
test['rubert_base_trained'] = rubert_base_pred['probability']

rubert_base_pred_rev = pd.read_csv(
    RUBERT_BASE_TEST_PREDS_REV_PATH + 'rubert_ZAEBAL_SUKA_REV.csv'
).rename(columns={'base_id': 'variantid_1', 'cand_id': 'variantid_2'})
rubert_base_pred_rev = rubert_base_pred_rev.sort_values(by=['variantid_1', 'variantid_2']).reset_index(drop=True)
test['rubert_base_trained_rev'] = rubert_base_pred_rev['probability']

del rubert_base_pred, rubert_base_pred_rev
gc.collect()

# rubert base test tta
if USE_MEAN_BASE_AND_REV:
    test['rubert_base_trained_tta'] = (test['rubert_base_trained'] + test['rubert_base_trained_rev']) / 2
    del test['rubert_base_trained'],  test['rubert_base_trained_rev']
    gc.collect()

# --- sample!!! ---
train = train.sample(len(train), random_state=42)

# trained ft (именно после сэмпла! тут уже все карты в нужном порядке разложены)
fasttext_train = joblib.load(FT_PREDS_PATH + 'oof_preds.pkl')
fasttext_test = joblib.load(FT_PREDS_PATH + 'test_preds.pkl')
fasttext_train_rev = joblib.load(FT_PREDS_PATH + 'oof_preds_rev.pkl')
fasttext_test_rev = joblib.load(FT_PREDS_PATH + 'test_preds_rev.pkl')

train['fasttext'] = fasttext_train
test['fasttext'] = fasttext_test
train['fasttext_rev'] = fasttext_train_rev
test['fasttext_rev'] = fasttext_test_rev

del fasttext_train, fasttext_test, fasttext_train_rev, fasttext_test_rev
gc.collect()

# fasttext tta
if USE_MEAN_BASE_AND_REV:
    train['fasttext_tta'] = (train['fasttext'] + train['fasttext_rev']) / 2
    test['fasttext_tta'] = (test['fasttext'] + test['fasttext_rev']) / 2
    del train['fasttext'], train['fasttext_rev']
    del test['fasttext'], test['fasttext_rev']
    gc.collect()

# trained rubert-base train (именно после сэмпла! тут уже все карты в нужном порядке разложены)
rubert_base_oof = joblib.load(RUBERT_BASE_OOF_PATH + 'oof_preds_rubert_base.joblib')
train['rubert_base_trained'] = rubert_base_oof

rubert_base_oof_rev = joblib.load(RUBERT_BASE_OOF_REV_PATH + 'oof_preds_rubert_base_rev.joblib')
train['rubert_base_trained_rev'] = rubert_base_oof_rev

del rubert_base_oof, rubert_base_oof_rev
gc.collect()

# rubert train test tta
if USE_MEAN_BASE_AND_REV:
    train['rubert_base_trained_tta'] = (train['rubert_base_trained'] + train['rubert_base_trained_rev']) / 2
    del train['rubert_base_trained'],  train['rubert_base_trained_rev']
    gc.collect()

# add rouge features (w/ tta)

train_rouge = pd.read_csv(ROUGE_PATH + 'train_rouge.csv')
test_rouge = pd.read_csv(ROUGE_PATH + 'test_rouge.csv')

train_rouge = train_rouge.sort_values(by=['variantid_1', 'variantid_2']).reset_index(drop=True)
test_rouge = test_rouge.sort_values(by=['variantid_1', 'variantid_2']).reset_index(drop=True)

train['rouge_1'] = train_rouge['rouge_1']
train['rouge_2'] = train_rouge['rouge_2']
train['rouge_3'] = train_rouge['rouge_3']
train['rouge_4'] = train_rouge['rouge_4']
train['rouge_s4'] = train_rouge['rouge_s4']
train['rouge_su4'] = train_rouge['rouge_su4']

test['rouge_1'] = test_rouge['rouge_1']
test['rouge_2'] = test_rouge['rouge_2']
test['rouge_3'] = test_rouge['rouge_3']
test['rouge_4'] = test_rouge['rouge_4']
test['rouge_s4'] = test_rouge['rouge_s4']
test['rouge_su4'] = test_rouge['rouge_su4']
# Out:
# userbge_cossims_train.shape=(125303, 3)
# userbge_cossims_train.shape=(250606, 3)
# userbge_cossims_train.shape=(375909, 3)
# userbge_cossims_train.shape=(501212, 3)
# userbge_cossims_train.shape=(626515, 3)
# userbge_cossims_train.shape=(751818, 3)
# userbge_cossims_train.shape=(877121, 3)
# userbge_cossims_train.shape=(1002424, 3)
# userbge_cossims_train.shape=(1127727, 3)
# userbge_cossims_train.shape=(1253030, 3)
# userbge_cossims_train.shape=(1378333, 3)
# userbge_cossims_train.shape=(1503636, 3)
# userbge_cossims_train.shape=(1628939, 3)
# userbge_cossims_train.shape=(1754242, 3)
# userbge_cossims_train.shape=(1879555, 3)
# userbge_cossims_test.shape=(125000, 3)
# userbge_cossims_test.shape=(250000, 3)
# userbge_cossims_test.shape=(375000, 3)
# userbge_cossims_test.shape=(500000, 3)

# %%
# pl_test = test.copy()
# pl_test = pl_test.sort_values(by=['variantid_1', 'variantid_2'])

# top_submit = pd.read_csv('/kaggle/input/top-test-submit-13-05/ZHIV_1_25COEF_2lama_and_cats_cbs_BLENDED_w_CATS1_0_5CAT.csv')
# top_submit = top_submit.sort_values(by=['base_id', 'cand_id'])

# pl_test = pl_test.reset_index(drop=True)
# top_submit = top_submit.reset_index(drop=True)

# pl_test['is_double'] = top_submit['probability']

# pl_test = pl_test[pl_test['unique_cat_1'].isin(['Услуги_Услуги', 'Недвижимость_Недвижимость', 'Работа_Работа'])]

# pl_test = pl_test[~pl_test['is_double'].between(0.02, 0.98)]
# pl_test['is_double'] = np.where(
#     pl_test['is_double'] < 0.02, 0, 
#     np.where(pl_test['is_double'] > 0.98, 1, pl_test['is_double'])
# )
# pl_test['group_id'] = 777777

# train = pd.concat([train, pl_test], axis=0).reset_index(drop=True)

# %%
train.drop(columns=['variantid_1', 'variantid_2', 'base_title_image', 'cand_title_image'], axis=1, inplace=True)
test.drop(columns=['variantid_1', 'variantid_2', 'base_title_image', 'cand_title_image'], axis=1, inplace=True)
train.drop(columns=['action_date'], inplace=True)

# %%
# cat_mapping = {
#     '1.0': 'True',
#     '0.0': 'False'
# }

# %%
# test['category_level_1_match'] = test['category_level_1_match'].map(cat_mapping)
# test['category_level_2_match'] = test['category_level_2_match'].map(cat_mapping)

# %%
features = [col for col in train.columns if col not in ['group_id', 'is_double']]
target = 'is_double'

# %%
gc.collect()
# Out:
# 0

# %%
len(features)
# Out:
# 470

# %%
def pr_auc(y_true, y_pred):
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    return auc(recall, precision)

# %%
def prauc_metric(y_true, y_pred, sample_weight, **kwargs):
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    return auc(recall, precision)

# %%
N_THREADS = 4
N_FOLDS = 10
RANDOM_STATE = 42
TIMEOUT = 11 * 3600
TARGET_NAME = 'is_double'
GROUP = 'group_id'

# %%
np.random.seed(RANDOM_STATE)
torch.set_num_threads(N_THREADS)

# %%
task = Task('binary', metric=prauc_metric, greater_is_better=True)

# %%
roles = {
    'target': TARGET_NAME,
    'drop': [GROUP],
    'category': cat_features,
    'group': [GROUP]
}

# %%
kittens = ['Готовый бизнес и оборудование', 'Для дома и дачи', 'Личные вещи', 'Электроника', 'Хобби и отдых', 'Транспорт', 'Животные'] # котики котята понимаете ????

# %%
categories = train['unique_cat_1'].unique()
categories = [cat.split('_')[0] for cat in categories if cat.split('_')[0] == cat.split('_')[1]]

progress_bar = tqdm(categories)

for category in progress_bar:
    progress_bar.set_description(f"{category}=")

    # if category != kittens[0]:
    #     continue
    # else:
    #     print(f'вооо моя любимая категория {category}')

    train_category = train[train['unique_cat_1'] == f'{category}_{category}']
    test_category = test[test['unique_cat_1'] == f'{category}_{category}']

    automl = TabularUtilizedAutoML(
        task=task,
        timeout=TIMEOUT,
        cpu_limit=N_THREADS,
        selection_params={'mode': 0},
        tuning_params={'max_tuning_time': 3600 * 2.5, 'max_tuning_iter': 100},
        reader_params={'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE},
        general_params={'use_algos': [['lgb', 'lgb_tuned', 'cb', 'cb_tuned', 'xgb', 'xgb_tuned']]},
        gpu_ids='0,1'
    )

    oof_pred = automl.fit_predict(train_category, roles=roles, verbose=3)
    oof_prauc = pr_auc(train_category[TARGET_NAME].values, oof_pred.data[:, 0])

    model_filename = f"automl_model_{category}_{oof_prauc}.joblib"
    pred_filename = f"test_pred_{category}_{oof_prauc}.joblib"
    
    test_pred = automl.predict(test_category)

    joblib.dump(automl, model_filename)
    joblib.dump(test_pred, pred_filename)
    
    print(f"\n{category=} {oof_prauc=}")
    print(automl.create_model_str_desc())

    del automl, oof_pred, test_pred, train_category, test_category
    gc.collect()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# вооо моя любимая категория Готовый бизнес и оборудование
# [18:15:41] Start automl utilizator with listed constraints:
# [18:15:41] - time: 39600.00 seconds
# [18:15:41] - CPU: 4 cores
# [18:15:41] - memory: 16 GB
#
# [18:15:41] If one preset completes earlier, next preset configuration will be started
#
# [18:15:41] ==================================================
# [18:15:41] Start 0 automl preset configuration:
# [18:15:41] conf_0_sel_type_0.yml, random state: {'reader_params': {'random_state': 42}, 'nn_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# [18:15:41] Found reader_params in kwargs, need to combine
# [18:15:41] Merged variant for reader_params = {'n_jobs': 4, 'cv': 10, 'random_state': 42}
# [18:15:41] Found general_params in kwargs, need to combine
# [18:15:41] Merged variant for general_params = {'use_algos': [['lgb', 'lgb_tuned', 'cb', 'cb_tuned', 'xgb', 'xgb_tuned']], 'return_all_predictions': False}
# [18:15:41] Stdout logging level is INFO3.
# [18:15:41] Task: binary
#
# [18:15:41] Start automl preset with listed constraints:
# [18:15:41] - time: 39600.00 seconds
# [18:15:41] - CPU: 4 cores
# [18:15:41] - memory: 16 GB
#
# [18:15:41] Train data shape: (231739, 472)
#
# [18:16:37] Feats was rejected during automatic roles guess: []
# [18:16:38] Layer 1 train process start. Time left 39542.63 secs
# [18:17:02] Start fitting Lvl_0_Pipe_0_Mod_0_LightGBM ...
# [18:17:02] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:17:11] Training until validation scores don't improve for 100 rounds
# [18:17:29] [100]	valid's binary_logloss: 0.00810482	valid's Opt metric: 0.298806
# [18:17:49] [200]	valid's binary_logloss: 0.00463461	valid's Opt metric: 0.428947
# [18:18:05] [300]	valid's binary_logloss: 0.00403993	valid's Opt metric: 0.422268
# [18:18:15] Early stopping, best iteration is:
# [250]	valid's binary_logloss: 0.00425237	valid's Opt metric: 0.467061
# [18:18:16] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:18:25] Training until validation scores don't improve for 100 rounds
# [18:18:42] [100]	valid's binary_logloss: 0.22009	valid's Opt metric: 0.63524
# [18:19:02] [200]	valid's binary_logloss: 0.219446	valid's Opt metric: 0.647263
# [18:19:11] Early stopping, best iteration is:
# [150]	valid's binary_logloss: 0.218413	valid's Opt metric: 0.646041
# [18:19:12] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:19:21] Training until validation scores don't improve for 100 rounds
# [18:19:39] [100]	valid's binary_logloss: 0.159894	valid's Opt metric: 0.823932
# [18:19:58] [200]	valid's binary_logloss: 0.152802	valid's Opt metric: 0.829366
# [18:20:15] [300]	valid's binary_logloss: 0.151249	valid's Opt metric: 0.829854
# [18:20:30] Early stopping, best iteration is:
# [283]	valid's binary_logloss: 0.151072	valid's Opt metric: 0.830339
# [18:20:31] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:20:40] Training until validation scores don't improve for 100 rounds
# [18:20:59] [100]	valid's binary_logloss: 0.213214	valid's Opt metric: 0.370049
# [18:21:17] [200]	valid's binary_logloss: 0.210574	valid's Opt metric: 0.398468
# [18:21:35] [300]	valid's binary_logloss: 0.210478	valid's Opt metric: 0.407521
# [18:21:49] Early stopping, best iteration is:
# [261]	valid's binary_logloss: 0.209731	valid's Opt metric: 0.405174
# [18:21:50] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:22:00] Training until validation scores don't improve for 100 rounds
# [18:22:18] [100]	valid's binary_logloss: 0.1697	valid's Opt metric: 0.621385
# [18:22:38] [200]	valid's binary_logloss: 0.170419	valid's Opt metric: 0.620504
# [18:22:41] Early stopping, best iteration is:
# [123]	valid's binary_logloss: 0.168762	valid's Opt metric: 0.622991
# [18:22:42] ===== Start working with fold 5 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:22:51] Training until validation scores don't improve for 100 rounds
# [18:23:11] [100]	valid's binary_logloss: 0.131261	valid's Opt metric: 0.400311
# [18:23:29] [200]	valid's binary_logloss: 0.130758	valid's Opt metric: 0.401349
# [18:23:34] Early stopping, best iteration is:
# [119]	valid's binary_logloss: 0.130169	valid's Opt metric: 0.403521
# [18:23:34] ===== Start working with fold 6 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:23:44] Training until validation scores don't improve for 100 rounds
# [18:24:00] [100]	valid's binary_logloss: 0.415484	valid's Opt metric: 0.495834
# [18:24:03] Early stopping, best iteration is:
# [16]	valid's binary_logloss: 0.407509	valid's Opt metric: 0.505445
# [18:24:04] ===== Start working with fold 7 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:24:13] Training until validation scores don't improve for 100 rounds
# [18:24:30] [100]	valid's binary_logloss: 0.20716	valid's Opt metric: 0.665535
# [18:24:49] [200]	valid's binary_logloss: 0.206259	valid's Opt metric: 0.670355
# [18:24:55] Early stopping, best iteration is:
# [134]	valid's binary_logloss: 0.205513	valid's Opt metric: 0.67037
# [18:24:55] ===== Start working with fold 8 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:25:04] Training until validation scores don't improve for 100 rounds
# [18:25:23] [100]	valid's binary_logloss: 0.179864	valid's Opt metric: 0.478846
# [18:25:43] [200]	valid's binary_logloss: 0.173906	valid's Opt metric: 0.503474
# [18:26:00] [300]	valid's binary_logloss: 0.174413	valid's Opt metric: 0.505083
# [18:26:07] Early stopping, best iteration is:
# [241]	valid's binary_logloss: 0.173448	valid's Opt metric: 0.506036
# [18:26:08] ===== Start working with fold 9 for Lvl_0_Pipe_0_Mod_0_LightGBM =====
# [18:26:17] Training until validation scores don't improve for 100 rounds
# [18:26:35] [100]	valid's binary_logloss: 0.14391	valid's Opt metric: 0.549997
# [18:26:54] [200]	valid's binary_logloss: 0.140637	valid's Opt metric: 0.553781
# [18:27:12] [300]	valid's binary_logloss: 0.138277	valid's Opt metric: 0.566278
# [18:27:30] [400]	valid's binary_logloss: 0.139233	valid's Opt metric: 0.566969
# [18:27:34] Early stopping, best iteration is:
# [325]	valid's binary_logloss: 0.138046	valid's Opt metric: 0.569127
# [18:27:35] Fitting Lvl_0_Pipe_0_Mod_0_LightGBM finished. score = 0.5871004957252253
# [18:27:35] Lvl_0_Pipe_0_Mod_0_LightGBM fitting and predicting completed
# [18:27:35] Start hyperparameters optimization for Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM ... Time budget is 6928.57 secs
# [18:27:35] Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# [18:27:44] Training until validation scores don't improve for 100 rounds
# [18:28:12] [100]	valid's binary_logloss: 0.00769532	valid's Opt metric: 0.23798
# [18:28:21] Early stopping, best iteration is:
# [27]	valid's binary_logloss: 0.0397952	valid's Opt metric: 0.306984
# [18:28:21] Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125} scored 0.3069837080504794 in 0:00:46.306531
# [18:28:30] Training until validation scores don't improve for 100 rounds
# [18:28:40] [100]	valid's binary_logloss: 0.00941829	valid's Opt metric: 0.410214
# [18:28:51] [200]	valid's binary_logloss: 0.00574142	valid's Opt metric: 0.478036
# [18:29:00] [300]	valid's binary_logloss: 0.00481929	valid's Opt metric: 0.521535
# [18:29:09] [400]	valid's binary_logloss: 0.00430331	valid's Opt metric: 0.462124
# [18:29:13] Early stopping, best iteration is:
# [341]	valid's binary_logloss: 0.00467178	valid's Opt metric: 0.537082
# [18:29:13] Trial 2 with hyperparameters {'feature_fraction': 0.5780093202212182, 'num_leaves': 53, 'bagging_fraction': 0.5290418060840998, 'min_sum_hessian_in_leaf': 2.9154431891537547} scored 0.5370820478893118 in 0:00:51.880259
# [18:29:23] Training until validation scores don't improve for 100 rounds
# [18:29:43] [100]	valid's binary_logloss: 0.00800693	valid's Opt metric: 0.306652
# [18:29:44] Early stopping, best iteration is:
# [4]	valid's binary_logloss: 0.0879179	valid's Opt metric: 0.368234
# [18:29:44] Trial 3 with hyperparameters {'feature_fraction': 0.8005575058716043, 'num_leaves': 185, 'bagging_fraction': 0.5102922471479012, 'min_sum_hessian_in_leaf': 7.579479953348009} scored 0.3682342957298262 in 0:00:30.678505
# [18:29:53] Training until validation scores don't improve for 100 rounds
# [18:30:09] [100]	valid's binary_logloss: 0.00902206	valid's Opt metric: 0.345
# [18:30:09] Early stopping, best iteration is:
# [1]	valid's binary_logloss: 0.0985467	valid's Opt metric: 0.45824
# [18:30:09] Trial 4 with hyperparameters {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254} scored 0.4582403438148849 in 0:00:25.608197
# [18:30:19] Training until validation scores don't improve for 100 rounds
# [18:30:38] [100]	valid's binary_logloss: 0.00814491	valid's Opt metric: 0.428174
# [18:30:55] Early stopping, best iteration is:
# [99]	valid's binary_logloss: 0.00825607	valid's Opt metric: 0.435611
# [18:30:55] Trial 5 with hyperparameters {'feature_fraction': 0.6521211214797689, 'num_leaves': 141, 'bagging_fraction': 0.7159725093210578, 'min_sum_hessian_in_leaf': 0.014618962793704957} scored 0.43561110582991186 in 0:00:45.993131
# [18:31:05] Training until validation scores don't improve for 100 rounds
# [18:31:17] [100]	valid's binary_logloss: 0.00945243	valid's Opt metric: 0.348821
# [18:31:17] Early stopping, best iteration is:
# [2]	valid's binary_logloss: 0.0956772	valid's Opt metric: 0.393191
# [18:31:17] Trial 6 with hyperparameters {'feature_fraction': 0.8059264473611898, 'num_leaves': 49, 'bagging_fraction': 0.6460723242676091, 'min_sum_hessian_in_leaf': 0.029204338471814112} scored 0.3931913218538433 in 0:00:21.984658
# [18:31:26] Training until validation scores don't improve for 100 rounds
# [18:31:50] [100]	valid's binary_logloss: 0.00765151	valid's Opt metric: 0.362856
# [18:32:05] Early stopping, best iteration is:
# [60]	valid's binary_logloss: 0.0155791	valid's Opt metric: 0.441339
# [18:32:05] Trial 7 with hyperparameters {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326} scored 0.4413390911142035 in 0:00:47.359663
# [18:32:14] Training until validation scores don't improve for 100 rounds
# [18:32:25] [100]	valid's binary_logloss: 0.0106632	valid's Opt metric: 0.50441
# [18:32:37] [200]	valid's binary_logloss: 0.00682757	valid's Opt metric: 0.543516
# [18:32:45] Early stopping, best iteration is:
# [184]	valid's binary_logloss: 0.00695468	valid's Opt metric: 0.563748
# [18:32:45] Trial 8 with hyperparameters {'feature_fraction': 0.7962072844310213, 'num_leaves': 27, 'bagging_fraction': 0.8037724259507192, 'min_sum_hessian_in_leaf': 0.004809461967501573} scored 0.563747730216526 in 0:00:40.192643
# [18:32:54] Training until validation scores don't improve for 100 rounds
# [18:33:18] [100]	valid's binary_logloss: 0.00743722	valid's Opt metric: 0.556126
# [18:33:26] Early stopping, best iteration is:
# [34]	valid's binary_logloss: 0.0317396	valid's Opt metric: 0.599088
# [18:33:26] Trial 9 with hyperparameters {'feature_fraction': 0.5325257964926398, 'num_leaves': 243, 'bagging_fraction': 0.9828160165372797, 'min_sum_hessian_in_leaf': 1.7123375973163988} scored 0.5990879988316469 in 0:00:41.425001
# [18:33:35] Training until validation scores don't improve for 100 rounds
# [18:33:48] [100]	valid's binary_logloss: 0.00947064	valid's Opt metric: 0.307374
# [18:33:59] [200]	valid's binary_logloss: 0.00590787	valid's Opt metric: 0.328464
# [18:34:00] Early stopping, best iteration is:
# [118]	valid's binary_logloss: 0.00792538	valid's Opt metric: 0.354811
# [18:34:01] Trial 10 with hyperparameters {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026} scored 0.3548111574016303 in 0:00:34.176366
# [18:34:10] Training until validation scores don't improve for 100 rounds
# [18:34:36] [100]	valid's binary_logloss: 0.00769624	valid's Opt metric: 0.538339
# [18:35:03] [200]	valid's binary_logloss: 0.00433786	valid's Opt metric: 0.552507
# [18:35:28] [300]	valid's binary_logloss: 0.00364995	valid's Opt metric: 0.472259
# [18:35:32] Early stopping, best iteration is:
# [220]	valid's binary_logloss: 0.00413179	valid's Opt metric: 0.582699
# [18:35:33] Trial 11 with hyperparameters {'feature_fraction': 0.5102734049121491, 'num_leaves': 129, 'bagging_fraction': 0.9847685553939328, 'min_sum_hessian_in_leaf': 0.6895398745616549} scored 0.5826988693945906 in 0:01:31.911107
# [18:35:41] Training until validation scores don't improve for 100 rounds
# [18:36:06] [100]	valid's binary_logloss: 0.00834622	valid's Opt metric: 0.453004
# [18:36:15] Early stopping, best iteration is:
# [36]	valid's binary_logloss: 0.0311884	valid's Opt metric: 0.55274
# [18:36:15] Trial 12 with hyperparameters {'feature_fraction': 0.5072704375811822, 'num_leaves': 112, 'bagging_fraction': 0.993551055264076, 'min_sum_hessian_in_leaf': 1.107320396163833} scored 0.5527402020923178 in 0:00:42.551182
# [18:36:24] Training until validation scores don't improve for 100 rounds
# [18:36:51] [100]	valid's binary_logloss: 0.00786905	valid's Opt metric: 0.463454
# [18:36:59] Early stopping, best iteration is:
# [32]	valid's binary_logloss: 0.03495	valid's Opt metric: 0.545425
# [18:36:59] Trial 13 with hyperparameters {'feature_fraction': 0.5171661033420644, 'num_leaves': 133, 'bagging_fraction': 0.9977994648804881, 'min_sum_hessian_in_leaf': 0.6146439247862419} scored 0.5454248527704828 in 0:00:44.352699
# [18:37:08] Training until validation scores don't improve for 100 rounds
# [18:37:34] [100]	valid's binary_logloss: 0.00755884	valid's Opt metric: 0.336848
# [18:37:54] Early stopping, best iteration is:
# [74]	valid's binary_logloss: 0.0115774	valid's Opt metric: 0.451231
# [18:37:55] Trial 14 with hyperparameters {'feature_fraction': 0.5889354671830282, 'num_leaves': 254, 'bagging_fraction': 0.9258956616045496, 'min_sum_hessian_in_leaf': 1.2366446565859224} scored 0.4512306125088092 in 0:00:55.100710
# [18:38:03] Training until validation scores don't improve for 100 rounds
# [18:38:24] [100]	valid's binary_logloss: 0.0078209	valid's Opt metric: 0.4495
# [18:38:44] [200]	valid's binary_logloss: 0.00429887	valid's Opt metric: 0.470118
# [18:38:54] Early stopping, best iteration is:
# [156]	valid's binary_logloss: 0.00489286	valid's Opt metric: 0.523842
# [18:38:54] Trial 15 with hyperparameters {'feature_fraction': 0.5800269239957762, 'num_leaves': 176, 'bagging_fraction': 0.91637235233837, 'min_sum_hessian_in_leaf': 6.194682586840606} scored 0.5238420465432074 in 0:00:59.598724
# [18:39:03] Training until validation scores don't improve for 100 rounds
# [18:39:24] [100]	valid's binary_logloss: 0.00857255	valid's Opt metric: 0.344185
# [18:39:25] Early stopping, best iteration is:
# [3]	valid's binary_logloss: 0.0918715	valid's Opt metric: 0.407059
# [18:39:25] Trial 16 with hyperparameters {'feature_fraction': 0.9559583616089686, 'num_leaves': 94, 'bagging_fraction': 0.7528545008858365, 'min_sum_hessian_in_leaf': 0.2519249318754148} scored 0.40705876369449245 in 0:00:30.369746
# [18:39:33] Training until validation scores don't improve for 100 rounds
# [18:40:00] [100]	valid's binary_logloss: 0.00799577	valid's Opt metric: 0.446211
# [18:40:10] Early stopping, best iteration is:
# [36]	valid's binary_logloss: 0.0305757	valid's Opt metric: 0.521275
# [18:40:10] Trial 17 with hyperparameters {'feature_fraction': 0.5076462603927838, 'num_leaves': 152, 'bagging_fraction': 0.9232524773594687, 'min_sum_hessian_in_leaf': 2.206252551696602} scored 0.5212745279007044 in 0:00:45.095304
# [18:40:18] Training until validation scores don't improve for 100 rounds
# [18:40:43] [100]	valid's binary_logloss: 0.00745472	valid's Opt metric: 0.369857
# [18:41:07] [200]	valid's binary_logloss: 0.00418884	valid's Opt metric: 0.41843
# [18:41:20] Early stopping, best iteration is:
# [163]	valid's binary_logloss: 0.00460513	valid's Opt metric: 0.479267
# [18:41:21] Trial 18 with hyperparameters {'feature_fraction': 0.5974450063091681, 'num_leaves': 213, 'bagging_fraction': 0.9589302577263387, 'min_sum_hessian_in_leaf': 0.4524542399915613} scored 0.47926698226035136 in 0:01:11.101429
# [18:41:29] Training until validation scores don't improve for 100 rounds
# [18:41:55] [100]	valid's binary_logloss: 0.0085206	valid's Opt metric: 0.394345
# [18:42:03] Early stopping, best iteration is:
# [33]	valid's binary_logloss: 0.0338211	valid's Opt metric: 0.447909
# [18:42:03] Trial 19 with hyperparameters {'feature_fraction': 0.5463757123570128, 'num_leaves': 95, 'bagging_fraction': 0.8486646961720588, 'min_sum_hessian_in_leaf': 0.10318136047371097} scored 0.4479092897906064 in 0:00:42.223331
# [18:42:11] Training until validation scores don't improve for 100 rounds
# [18:42:42] [100]	valid's binary_logloss: 0.00771291	valid's Opt metric: 0.238345
# [18:42:48] Early stopping, best iteration is:
# [21]	valid's binary_logloss: 0.0485072	valid's Opt metric: 0.358275
# [18:42:48] Trial 20 with hyperparameters {'feature_fraction': 0.8649174147658507, 'num_leaves': 223, 'bagging_fraction': 0.7559956394678677, 'min_sum_hessian_in_leaf': 2.9332288822079025} scored 0.35827483854556225 in 0:00:45.307336
# [18:42:56] Training until validation scores don't improve for 100 rounds
# [18:43:19] [100]	valid's binary_logloss: 0.00792956	valid's Opt metric: 0.448735
# [18:43:39] [200]	valid's binary_logloss: 0.00427308	valid's Opt metric: 0.517987
# [18:43:58] [300]	valid's binary_logloss: 0.00367255	valid's Opt metric: 0.543114
# [18:44:17] [400]	valid's binary_logloss: 0.00331076	valid's Opt metric: 0.532436
# [18:44:26] Early stopping, best iteration is:
# [349]	valid's binary_logloss: 0.00345344	valid's Opt metric: 0.552406
# [18:44:26] Trial 21 with hyperparameters {'feature_fraction': 0.632120509589315, 'num_leaves': 165, 'bagging_fraction': 0.9018655666885802, 'min_sum_hessian_in_leaf': 0.5753601674815134} scored 0.5524057131562001 in 0:01:37.989725
# [18:44:34] Training until validation scores don't improve for 100 rounds
# [18:44:52] [100]	valid's binary_logloss: 0.00852929	valid's Opt metric: 0.429294
# [18:44:52] Early stopping, best iteration is:
# [1]	valid's binary_logloss: 0.0988873	valid's Opt metric: 0.536448
# [18:44:52] Trial 22 with hyperparameters {'feature_fraction': 0.7472223931930823, 'num_leaves': 78, 'bagging_fraction': 0.7947992509228795, 'min_sum_hessian_in_leaf': 0.0010335797240302036} scored 0.5364482143803421 in 0:00:25.461658
# [18:44:59] Training until validation scores don't improve for 100 rounds
# [18:45:21] [100]	valid's binary_logloss: 0.00795186	valid's Opt metric: 0.344036
# [18:45:22] Early stopping, best iteration is:
# [4]	valid's binary_logloss: 0.0883975	valid's Opt metric: 0.379221
# [18:45:22] Trial 23 with hyperparameters {'feature_fraction': 0.8155028085257771, 'num_leaves': 121, 'bagging_fraction': 0.8034126372066358, 'min_sum_hessian_in_leaf': 0.0031116903968815904} scored 0.37922092012451564 in 0:00:30.403503
# [18:45:30] Training until validation scores don't improve for 100 rounds
# [18:45:40] [100]	valid's binary_logloss: 0.0103238	valid's Opt metric: 0.310636
# [18:45:40] Early stopping, best iteration is:
# [2]	valid's binary_logloss: 0.0962721	valid's Opt metric: 0.482836
# [18:45:40] Trial 24 with hyperparameters {'feature_fraction': 0.8553664950493697, 'num_leaves': 25, 'bagging_fraction': 0.7033673238432996, 'min_sum_hessian_in_leaf': 0.012593966891684315} scored 0.48283611246654207 in 0:00:18.204055
# [18:45:48] Training until validation scores don't improve for 100 rounds
# [18:45:59] [100]	valid's binary_logloss: 0.0113262	valid's Opt metric: 0.438514
# [18:46:09] [200]	valid's binary_logloss: 0.00657355	valid's Opt metric: 0.470818
# [18:46:17] [300]	valid's binary_logloss: 0.00569167	valid's Opt metric: 0.473435
# [18:46:24] Early stopping, best iteration is:
# [276]	valid's binary_logloss: 0.00590193	valid's Opt metric: 0.502998
# [18:46:24] Trial 25 with hyperparameters {'feature_fraction': 0.7205564086610236, 'num_leaves': 18, 'bagging_fraction': 0.9564124123843677, 'min_sum_hessian_in_leaf': 0.20314058348860564} scored 0.502997767999563 in 0:00:44.005690
# [18:46:32] Training until validation scores don't improve for 100 rounds
# [18:46:58] [100]	valid's binary_logloss: 0.00758703	valid's Opt metric: 0.291028
# [18:47:03] Early stopping, best iteration is:
# [19]	valid's binary_logloss: 0.0515631	valid's Opt metric: 0.421472
# [18:47:04] Trial 26 with hyperparameters {'feature_fraction': 0.7746677890305673, 'num_leaves': 190, 'bagging_fraction': 0.8769140857759561, 'min_sum_hessian_in_leaf': 0.001094410546325988} scored 0.4214719579845777 in 0:00:39.101732
# [18:47:11] Training until validation scores don't improve for 100 rounds
# [18:47:42] [100]	valid's binary_logloss: 0.00763685	valid's Opt metric: 0.315452
# [18:47:53] Early stopping, best iteration is:
# [37]	valid's binary_logloss: 0.0290315	valid's Opt metric: 0.419378
# [18:47:53] Trial 27 with hyperparameters {'feature_fraction': 0.5492229999946832, 'num_leaves': 229, 'bagging_fraction': 0.9610205876902643, 'min_sum_hessian_in_leaf': 1.3686174436895306} scored 0.41937763931834515 in 0:00:49.854263
# [18:48:01] Training until validation scores don't improve for 100 rounds
# [18:48:17] [100]	valid's binary_logloss: 0.00811712	valid's Opt metric: 0.328335
# [18:48:22] Early stopping, best iteration is:
# [28]	valid's binary_logloss: 0.0392146	valid's Opt metric: 0.427282
# [18:48:22] Trial 28 with hyperparameters {'feature_fraction': 0.6900913631930553, 'num_leaves': 100, 'bagging_fraction': 0.8163389865419242, 'min_sum_hessian_in_leaf': 0.05988565122365111} scored 0.4272824297957433 in 0:00:28.383912
# [18:48:30] Training until validation scores don't improve for 100 rounds
# [18:48:48] [100]	valid's binary_logloss: 0.00851384	valid's Opt metric: 0.344157
# [18:48:51] Early stopping, best iteration is:
# [18]	valid's binary_logloss: 0.054481	valid's Opt metric: 0.429399
# [18:48:51] Trial 29 with hyperparameters {'feature_fraction': 0.9920681804534548, 'num_leaves': 77, 'bagging_fraction': 0.6671876770805227, 'min_sum_hessian_in_leaf': 0.003183901967003354} scored 0.4293988226769477 in 0:00:29.544628
# [18:48:59] Training until validation scores don't improve for 100 rounds
# [18:49:23] [100]	valid's binary_logloss: 0.00781759	valid's Opt metric: 0.281993
# [18:49:48] [200]	valid's binary_logloss: 0.0045093	valid's Opt metric: 0.299267
# [18:50:11] Early stopping, best iteration is:
# [196]	valid's binary_logloss: 0.00455516	valid's Opt metric: 0.317836
# [18:50:11] Trial 30 with hyperparameters {'feature_fraction': 0.6223752669714424, 'num_leaves': 239, 'bagging_fraction': 0.8674417133409922, 'min_sum_hessian_in_leaf': 0.28240666398146613} scored 0.31783629975400307 in 0:01:19.623523
# [18:50:19] Training until validation scores don't improve for 100 rounds
# [18:50:41] [100]	valid's binary_logloss: 0.00782907	valid's Opt metric: 0.329294
# [18:50:44] Early stopping, best iteration is:
# [12]	valid's binary_logloss: 0.0661004	valid's Opt metric: 0.413669
# [18:50:44] Trial 31 with hyperparameters {'feature_fraction': 0.6907748491308748, 'num_leaves': 159, 'bagging_fraction': 0.8897141011558394, 'min_sum_hessian_in_leaf': 0.8082391279972981} scored 0.4136689266421626 in 0:00:32.739919
# [18:50:51] Training until validation scores don't improve for 100 rounds
# [18:51:16] [100]	valid's binary_logloss: 0.00819053	valid's Opt metric: 0.430708
# [18:51:23] Early stopping, best iteration is:
# [28]	valid's binary_logloss: 0.0400125	valid's Opt metric: 0.498596
# [18:51:23] Trial 32 with hyperparameters {'feature_fraction': 0.5319123517417491, 'num_leaves': 114, 'bagging_fraction': 0.9984625304083811, 'min_sum_hessian_in_leaf': 4.141521654099694} scored 0.4985960079087841 in 0:00:39.511290
# [18:51:31] Training until validation scores don't improve for 100 rounds
# [18:51:56] [100]	valid's binary_logloss: 0.00858332	valid's Opt metric: 0.358021
# [18:52:20] [200]	valid's binary_logloss: 0.00480938	valid's Opt metric: 0.449722
# [18:52:29] Early stopping, best iteration is:
# [141]	valid's binary_logloss: 0.00587779	valid's Opt metric: 0.502343
# [18:52:29] Trial 33 with hyperparameters {'feature_fraction': 0.5069389709742126, 'num_leaves': 119, 'bagging_fraction': 0.9773797748452828, 'min_sum_hessian_in_leaf': 4.068742788981587} scored 0.5023426251608766 in 0:01:05.733792
# [18:52:37] Training until validation scores don't improve for 100 rounds
# [18:52:55] [100]	valid's binary_logloss: 0.00779825	valid's Opt metric: 0.474034
# [18:53:12] [200]	valid's binary_logloss: 0.00446622	valid's Opt metric: 0.591146
# [18:53:28] [300]	valid's binary_logloss: 0.00371034	valid's Opt metric: 0.618454
# [18:53:39] Early stopping, best iteration is:
# [284]	valid's binary_logloss: 0.00382862	valid's Opt metric: 0.646511
# [18:53:39] Trial 34 with hyperparameters {'feature_fraction': 0.5616831888470788, 'num_leaves': 139, 'bagging_fraction': 0.9362224107749759, 'min_sum_hessian_in_leaf': 1.609775157737021} scored 0.6465111149929575 in 0:01:10.156759
# [18:53:48] Training until validation scores don't improve for 100 rounds
# [18:54:08] [100]	valid's binary_logloss: 0.00746355	valid's Opt metric: 0.423789
# [18:54:22] Early stopping, best iteration is:
# [57]	valid's binary_logloss: 0.0164225	valid's Opt metric: 0.487815
# [18:54:22] Trial 35 with hyperparameters {'feature_fraction': 0.550370566510675, 'num_leaves': 202, 'bagging_fraction': 0.9386482956418745, 'min_sum_hessian_in_leaf': 0.38804775746512893} scored 0.4878145522504873 in 0:00:42.486549
# [18:54:29] Training until validation scores don't improve for 100 rounds
# [18:54:42] [100]	valid's binary_logloss: 0.0088825	valid's Opt metric: 0.471071
# [18:54:56] [200]	valid's binary_logloss: 0.00544039	valid's Opt metric: 0.546907
# [18:55:07] [300]	valid's binary_logloss: 0.00475908	valid's Opt metric: 0.550387
# [18:55:17] [400]	valid's binary_logloss: 0.00438699	valid's Opt metric: 0.514641
# [18:55:26] Early stopping, best iteration is:
# [378]	valid's binary_logloss: 0.00450616	valid's Opt metric: 0.563772
# [18:55:27] Trial 36 with hyperparameters {'feature_fraction': 0.5606643234634816, 'num_leaves': 63, 'bagging_fraction': 0.9447656522863094, 'min_sum_hessian_in_leaf': 8.688260773067167} scored 0.563771933331559 in 0:01:04.958945
# [18:55:34] Training until validation scores don't improve for 100 rounds
# [18:55:47] [100]	valid's binary_logloss: 0.0088183	valid's Opt metric: 0.354777
# [18:56:01] [200]	valid's binary_logloss: 0.00534485	valid's Opt metric: 0.503534
# [18:56:05] Early stopping, best iteration is:
# [134]	valid's binary_logloss: 0.00667406	valid's Opt metric: 0.529069
# [18:56:05] Trial 37 with hyperparameters {'feature_fraction': 0.5657756578161672, 'num_leaves': 62, 'bagging_fraction': 0.945830937408817, 'min_sum_hessian_in_leaf': 9.101580983683553} scored 0.5290686237963932 in 0:00:38.308144
# [18:56:13] Training until validation scores don't improve for 100 rounds
# [18:56:32] [100]	valid's binary_logloss: 0.00803876	valid's Opt metric: 0.50717
# [18:56:35] Early stopping, best iteration is:
# [16]	valid's binary_logloss: 0.0581325	valid's Opt metric: 0.531084
# [18:56:35] Trial 38 with hyperparameters {'feature_fraction': 0.6042737120565524, 'num_leaves': 140, 'bagging_fraction': 0.9006649532171603, 'min_sum_hessian_in_leaf': 1.9083590169845963} scored 0.5310841855507854 in 0:00:30.067768
# [18:56:43] Training until validation scores don't improve for 100 rounds
# [18:57:05] [100]	valid's binary_logloss: 0.008193	valid's Opt metric: 0.261741
# [18:57:19] Early stopping, best iteration is:
# [63]	valid's binary_logloss: 0.0147195	valid's Opt metric: 0.437566
# [18:57:19] Trial 39 with hyperparameters {'feature_fraction': 0.6587968945429699, 'num_leaves': 181, 'bagging_fraction': 0.9720939103218647, 'min_sum_hessian_in_leaf': 5.598379908256046} scored 0.43756576301738 in 0:00:44.231341
# [18:57:27] Training until validation scores don't improve for 100 rounds
# [18:57:48] [100]	valid's binary_logloss: 0.00970073	valid's Opt metric: 0.414611
# [18:58:09] [200]	valid's binary_logloss: 0.00578703	valid's Opt metric: 0.486518
# [18:58:13] Early stopping, best iteration is:
# [123]	valid's binary_logloss: 0.00783139	valid's Opt metric: 0.51483
# [18:58:13] Trial 40 with hyperparameters {'feature_fraction': 0.5668180997021613, 'num_leaves': 42, 'bagging_fraction': 0.8422951113264495, 'min_sum_hessian_in_leaf': 9.492401350607368} scored 0.5148298460757275 in 0:00:54.004270
# [18:58:21] Training until validation scores don't improve for 100 rounds
# [18:58:37] [100]	valid's binary_logloss: 0.00871082	valid's Opt metric: 0.398775
# [18:58:52] [200]	valid's binary_logloss: 0.00509697	valid's Opt metric: 0.511648
# [18:58:58] Early stopping, best iteration is:
# [154]	valid's binary_logloss: 0.00562832	valid's Opt metric: 0.538426
# [18:58:59] Trial 41 with hyperparameters {'feature_fraction': 0.6165722708220366, 'num_leaves': 83, 'bagging_fraction': 0.9325897846335521, 'min_sum_hessian_in_leaf': 1.9296615667236252} scored 0.5384260520116209 in 0:00:45.303806
# [18:59:07] Training until validation scores don't improve for 100 rounds
# [18:59:22] [100]	valid's binary_logloss: 0.0100868	valid's Opt metric: 0.339669
# [18:59:22] Early stopping, best iteration is:
# [4]	valid's binary_logloss: 0.0901106	valid's Opt metric: 0.455874
# [18:59:22] Trial 42 with hyperparameters {'feature_fraction': 0.8786573830716804, 'num_leaves': 36, 'bagging_fraction': 0.9764130260626631, 'min_sum_hessian_in_leaf': 0.02103949451436472} scored 0.455874345415683 in 0:00:23.722203
# [18:59:30] Training until validation scores don't improve for 100 rounds
# [18:59:52] [100]	valid's binary_logloss: 0.00882051	valid's Opt metric: 0.38308
# [18:59:56] Early stopping, best iteration is:
# [21]	valid's binary_logloss: 0.0515717	valid's Opt metric: 0.418355
# [18:59:56] Trial 43 with hyperparameters {'feature_fraction': 0.5299308903659846, 'num_leaves': 66, 'bagging_fraction': 0.7830490167548361, 'min_sum_hessian_in_leaf': 0.9547669691814348} scored 0.41835532527365016 in 0:00:33.819778
# [19:00:04] Training until validation scores don't improve for 100 rounds
# [19:00:17] [100]	valid's binary_logloss: 0.0106939	valid's Opt metric: 0.372151
# [19:00:29] [200]	valid's binary_logloss: 0.00627443	valid's Opt metric: 0.401362
# [19:00:41] [300]	valid's binary_logloss: 0.00547332	valid's Opt metric: 0.36869
# [19:00:43] Early stopping, best iteration is:
# [221]	valid's binary_logloss: 0.00593273	valid's Opt metric: 0.430397
# [19:00:43] Trial 44 with hyperparameters {'feature_fraction': 0.7862103960918596, 'num_leaves': 55, 'bagging_fraction': 0.5998568825811558, 'min_sum_hessian_in_leaf': 0.17039660115001612} scored 0.4303965138194839 in 0:00:47.029205
# [19:00:51] Training until validation scores don't improve for 100 rounds
# [19:01:10] [100]	valid's binary_logloss: 0.0101103	valid's Opt metric: 0.383421
# [19:01:30] [200]	valid's binary_logloss: 0.00604867	valid's Opt metric: 0.485693
# [19:01:49] [300]	valid's binary_logloss: 0.00518517	valid's Opt metric: 0.513535
# [19:01:53] Early stopping, best iteration is:
# [221]	valid's binary_logloss: 0.00593011	valid's Opt metric: 0.540215
# [19:01:53] Trial 45 with hyperparameters {'feature_fraction': 0.5705646267853844, 'num_leaves': 35, 'bagging_fraction': 0.907569171127205, 'min_sum_hessian_in_leaf': 3.0927630261585755} scored 0.5402146001153542 in 0:01:10.130479
# [19:02:01] Training until validation scores don't improve for 100 rounds
# [19:02:18] [100]	valid's binary_logloss: 0.0112806	valid's Opt metric: 0.522627
# [19:02:34] [200]	valid's binary_logloss: 0.00611244	valid's Opt metric: 0.581027
# [19:02:51] [300]	valid's binary_logloss: 0.00537729	valid's Opt metric: 0.589313
# [19:02:58] Early stopping, best iteration is:
# [246]	valid's binary_logloss: 0.00550321	valid's Opt metric: 0.62243
# [19:02:58] Trial 46 with hyperparameters {'feature_fraction': 0.500143952973332, 'num_leaves': 24, 'bagging_fraction': 0.5414403310742755, 'min_sum_hessian_in_leaf': 1.5063329061004929} scored 0.6224295381120518 in 0:01:04.941200
# [19:03:06] Training until validation scores don't improve for 100 rounds
# [19:03:22] [100]	valid's binary_logloss: 0.012775	valid's Opt metric: 0.407701
# [19:03:38] [200]	valid's binary_logloss: 0.00688842	valid's Opt metric: 0.586091
# [19:03:54] [300]	valid's binary_logloss: 0.00623938	valid's Opt metric: 0.585673
# [19:04:09] [400]	valid's binary_logloss: 0.00556315	valid's Opt metric: 0.542577
# [19:04:15] Early stopping, best iteration is:
# [339]	valid's binary_logloss: 0.00611699	valid's Opt metric: 0.614672
# [19:04:15] Trial 47 with hyperparameters {'feature_fraction': 0.5014493493786027, 'num_leaves': 16, 'bagging_fraction': 0.5061088638582244, 'min_sum_hessian_in_leaf': 1.3570327872421173} scored 0.6146715804709704 in 0:01:16.847982
# [19:04:24] Training until validation scores don't improve for 100 rounds
# [19:04:51] [100]	valid's binary_logloss: 0.00743073	valid's Opt metric: 0.388678
# [19:05:20] [200]	valid's binary_logloss: 0.0041728	valid's Opt metric: 0.410675
# [19:05:30] Early stopping, best iteration is:
# [131]	valid's binary_logloss: 0.00551868	valid's Opt metric: 0.519902
# [19:05:31] Trial 48 with hyperparameters {'feature_fraction': 0.5241917931428622, 'num_leaves': 253, 'bagging_fraction': 0.5557341818575413, 'min_sum_hessian_in_leaf': 1.5494095478845988} scored 0.5199015076389591 in 0:01:15.541108
# [19:05:39] Training until validation scores don't improve for 100 rounds
# [19:05:54] [100]	valid's binary_logloss: 0.0111228	valid's Opt metric: 0.436955
# [19:06:08] Early stopping, best iteration is:
# [85]	valid's binary_logloss: 0.0134517	valid's Opt metric: 0.476332
# [19:06:09] Trial 49 with hyperparameters {'feature_fraction': 0.5049966940051758, 'num_leaves': 19, 'bagging_fraction': 0.5218926224884167, 'min_sum_hessian_in_leaf': 0.7135591365654325} scored 0.47633202556276083 in 0:00:37.842154
# [19:06:17] Training until validation scores don't improve for 100 rounds
# [19:06:41] [100]	valid's binary_logloss: 0.00804658	valid's Opt metric: 0.506731
# [19:07:05] [200]	valid's binary_logloss: 0.0044411	valid's Opt metric: 0.578554
# [19:07:21] Early stopping, best iteration is:
# [172]	valid's binary_logloss: 0.00488504	valid's Opt metric: 0.603544
# [19:07:22] Trial 50 with hyperparameters {'feature_fraction': 0.5329338922633987, 'num_leaves': 132, 'bagging_fraction': 0.5520921147525201, 'min_sum_hessian_in_leaf': 0.4500188007572929} scored 0.6035442425897288 in 0:01:13.024326
# [19:07:30] Training until validation scores don't improve for 100 rounds
# [19:07:49] [100]	valid's binary_logloss: 0.00916749	valid's Opt metric: 0.463908
# [19:08:09] [200]	valid's binary_logloss: 0.00523302	valid's Opt metric: 0.435426
# [19:08:19] Early stopping, best iteration is:
# [159]	valid's binary_logloss: 0.00609075	valid's Opt metric: 0.513722
# [19:08:19] Trial 51 with hyperparameters {'feature_fraction': 0.540052539312912, 'num_leaves': 48, 'bagging_fraction': 0.5031460419167044, 'min_sum_hessian_in_leaf': 0.374769738306828} scored 0.5137224718778886 in 0:00:57.738091
# [19:08:27] Training until validation scores don't improve for 100 rounds
# [19:08:50] [100]	valid's binary_logloss: 0.00816957	valid's Opt metric: 0.496692
# [19:09:14] [200]	valid's binary_logloss: 0.00463182	valid's Opt metric: 0.548689
# [19:09:27] Early stopping, best iteration is:
# [158]	valid's binary_logloss: 0.00529649	valid's Opt metric: 0.595746
# [19:09:27] Trial 52 with hyperparameters {'feature_fraction': 0.5002106606126623, 'num_leaves': 134, 'bagging_fraction': 0.5553634555146938, 'min_sum_hessian_in_leaf': 0.9963331886346423} scored 0.5957456649814308 in 0:01:07.745018
# [19:09:35] Training until validation scores don't improve for 100 rounds
# [19:10:00] [100]	valid's binary_logloss: 0.00786451	valid's Opt metric: 0.504747
# [19:10:02] Early stopping, best iteration is:
# [12]	valid's binary_logloss: 0.0676529	valid's Opt metric: 0.586766
# [19:10:02] Trial 53 with hyperparameters {'feature_fraction': 0.5279251632466995, 'num_leaves': 146, 'bagging_fraction': 0.5548153228121931, 'min_sum_hessian_in_leaf': 1.1044407436610646} scored 0.5867658374760701 in 0:00:35.342943
# [19:10:10] Training until validation scores don't improve for 100 rounds
# [19:10:34] [100]	valid's binary_logloss: 0.00803402	valid's Opt metric: 0.468467
# [19:10:58] [200]	valid's binary_logloss: 0.00487214	valid's Opt metric: 0.503312
# [19:11:11] Early stopping, best iteration is:
# [161]	valid's binary_logloss: 0.00547126	valid's Opt metric: 0.534967
# [19:11:12] Trial 54 with hyperparameters {'feature_fraction': 0.5855872707471067, 'num_leaves': 130, 'bagging_fraction': 0.550789684420228, 'min_sum_hessian_in_leaf': 2.5109134253804477} scored 0.5349670421020515 in 0:01:09.111926
# [19:11:20] Training until validation scores don't improve for 100 rounds
# [19:11:44] [100]	valid's binary_logloss: 0.0079472	valid's Opt metric: 0.402065
# [19:11:50] Early stopping, best iteration is:
# [19]	valid's binary_logloss: 0.0530364	valid's Opt metric: 0.464183
# [19:11:50] Trial 55 with hyperparameters {'feature_fraction': 0.5003804946720817, 'num_leaves': 173, 'bagging_fraction': 0.616996710721996, 'min_sum_hessian_in_leaf': 0.5044107607161434} scored 0.4641829061727317 in 0:00:38.342069
# [19:11:58] Training until validation scores don't improve for 100 rounds
# [19:12:19] [100]	valid's binary_logloss: 0.00837303	valid's Opt metric: 0.477481
# [19:12:33] Early stopping, best iteration is:
# [64]	valid's binary_logloss: 0.0152467	valid's Opt metric: 0.53933
# [19:12:33] Trial 56 with hyperparameters {'feature_fraction': 0.5262869838884403, 'num_leaves': 106, 'bagging_fraction': 0.5346192421160065, 'min_sum_hessian_in_leaf': 1.582811004344858} scored 0.5393297312308837 in 0:00:43.406698
# [19:12:41] Training until validation scores don't improve for 100 rounds
# [19:13:08] [100]	valid's binary_logloss: 0.00764003	valid's Opt metric: 0.511076
# [19:13:14] Early stopping, best iteration is:
# [22]	valid's binary_logloss: 0.0469285	valid's Opt metric: 0.539508
# [19:13:14] Trial 57 with hyperparameters {'feature_fraction': 0.5432710142067168, 'num_leaves': 194, 'bagging_fraction': 0.5827732525379513, 'min_sum_hessian_in_leaf': 1.0359192733572298} scored 0.5395075728240704 in 0:00:40.279690
# [19:13:21] Training until validation scores don't improve for 100 rounds
# [19:13:46] [100]	valid's binary_logloss: 0.00783078	valid's Opt metric: 0.539806
# [19:13:59] Early stopping, best iteration is:
# [49]	valid's binary_logloss: 0.0209469	valid's Opt metric: 0.593011
# [19:13:59] Trial 58 with hyperparameters {'feature_fraction': 0.5844377620667889, 'num_leaves': 158, 'bagging_fraction': 0.5781876894903767, 'min_sum_hessian_in_leaf': 4.0497215888777935} scored 0.5930107923552154 in 0:00:45.808846
# [19:14:07] Training until validation scores don't improve for 100 rounds
# [19:14:24] [100]	valid's binary_logloss: 0.0111639	valid's Opt metric: 0.427582
# [19:14:42] [200]	valid's binary_logloss: 0.00608614	valid's Opt metric: 0.479863
# [19:14:58] [300]	valid's binary_logloss: 0.00509567	valid's Opt metric: 0.472471
# [19:15:05] Early stopping, best iteration is:
# [238]	valid's binary_logloss: 0.00560218	valid's Opt metric: 0.562491
# [19:15:05] Trial 59 with hyperparameters {'feature_fraction': 0.5198245725815875, 'num_leaves': 29, 'bagging_fraction': 0.6243858457690731, 'min_sum_hessian_in_leaf': 0.146456228765874} scored 0.5624907607522254 in 0:01:05.792638
# [19:15:13] Training until validation scores don't improve for 100 rounds
# [19:15:34] [100]	valid's binary_logloss: 0.00875432	valid's Opt metric: 0.487804
# [19:15:44] Early stopping, best iteration is:
# [53]	valid's binary_logloss: 0.0198086	valid's Opt metric: 0.555587
# [19:15:44] Trial 60 with hyperparameters {'feature_fraction': 0.5000722872424258, 'num_leaves': 87, 'bagging_fraction': 0.5299553114781231, 'min_sum_hessian_in_leaf': 0.7178627136654776} scored 0.5555873856241449 in 0:00:38.679310
# [19:15:52] Training until validation scores don't improve for 100 rounds
# [19:16:16] [100]	valid's binary_logloss: 0.00830034	valid's Opt metric: 0.380209
# [19:16:18] Early stopping, best iteration is:
# [8]	valid's binary_logloss: 0.0773068	valid's Opt metric: 0.521744
# [19:16:18] Trial 61 with hyperparameters {'feature_fraction': 0.5550136139864181, 'num_leaves': 125, 'bagging_fraction': 0.6842826785241072, 'min_sum_hessian_in_leaf': 2.559659103682202} scored 0.5217443502215084 in 0:00:34.272619
# [19:16:26] Training until validation scores don't improve for 100 rounds
# [19:16:50] [100]	valid's binary_logloss: 0.00809716	valid's Opt metric: 0.375481
# [19:16:55] Early stopping, best iteration is:
# [22]	valid's binary_logloss: 0.0474785	valid's Opt metric: 0.488973
# [19:16:55] Trial 62 with hyperparameters {'feature_fraction': 0.5851171734544505, 'num_leaves': 147, 'bagging_fraction': 0.5699510310183171, 'min_sum_hessian_in_leaf': 3.9428482239864566} scored 0.48897284158831217 in 0:00:37.151883
# [19:17:03] Training until validation scores don't improve for 100 rounds
# [19:17:18] [100]	valid's binary_logloss: 0.00795978	valid's Opt metric: 0.489334
# [19:17:25] Early stopping, best iteration is:
# [50]	valid's binary_logloss: 0.0206782	valid's Opt metric: 0.535312
# [19:17:26] Trial 63 with hyperparameters {'feature_fraction': 0.6412438743210681, 'num_leaves': 136, 'bagging_fraction': 0.513424012901458, 'min_sum_hessian_in_leaf': 5.6056536254893645} scored 0.5353122642496175 in 0:00:30.130088
# [19:17:33] Training until validation scores don't improve for 100 rounds
# [19:17:51] [100]	valid's binary_logloss: 0.00791952	valid's Opt metric: 0.421993
# [19:18:08] [200]	valid's binary_logloss: 0.00449288	valid's Opt metric: 0.38303
# [19:18:15] Early stopping, best iteration is:
# [132]	valid's binary_logloss: 0.0060884	valid's Opt metric: 0.522408
# [19:18:15] Trial 64 with hyperparameters {'feature_fraction': 0.5982359715697984, 'num_leaves': 165, 'bagging_fraction': 0.5704621330480265, 'min_sum_hessian_in_leaf': 1.4884571908281543} scored 0.5224077714908997 in 0:00:49.322175
# [19:18:23] Training until validation scores don't improve for 100 rounds
# [19:18:49] [100]	valid's binary_logloss: 0.00787947	valid's Opt metric: 0.579741
# [19:19:06] Early stopping, best iteration is:
# [65]	valid's binary_logloss: 0.013635	valid's Opt metric: 0.594879
# [19:19:06] Trial 65 with hyperparameters {'feature_fraction': 0.5191521162450917, 'num_leaves': 227, 'bagging_fraction': 0.538147479203236, 'min_sum_hessian_in_leaf': 3.2402864343764084} scored 0.5948792483784531 in 0:00:50.757501
# [19:19:15] Training until validation scores don't improve for 100 rounds
# [19:19:40] [100]	valid's binary_logloss: 0.00755723	valid's Opt metric: 0.489067
# [19:19:48] Early stopping, best iteration is:
# [22]	valid's binary_logloss: 0.0471063	valid's Opt metric: 0.52131
# [19:19:48] Trial 66 with hyperparameters {'feature_fraction': 0.5418161169686144, 'num_leaves': 221, 'bagging_fraction': 0.541716356575069, 'min_sum_hessian_in_leaf': 1.9703236162897737} scored 0.5213102485365767 in 0:00:41.934404
# [19:19:55] Training until validation scores don't improve for 100 rounds
# [19:20:23] [100]	valid's binary_logloss: 0.00736694	valid's Opt metric: 0.514164
# [19:20:34] Early stopping, best iteration is:
# [38]	valid's binary_logloss: 0.0284489	valid's Opt metric: 0.551568
# [19:20:34] Trial 67 with hyperparameters {'feature_fraction': 0.5155569626268482, 'num_leaves': 240, 'bagging_fraction': 0.6403748281124999, 'min_sum_hessian_in_leaf': 0.9061110883808693} scored 0.5515682665255531 in 0:00:46.476404
# [19:20:42] Training until validation scores don't improve for 100 rounds
# [19:21:09] [100]	valid's binary_logloss: 0.00748847	valid's Opt metric: 0.531437
# [19:21:37] [200]	valid's binary_logloss: 0.00416874	valid's Opt metric: 0.545863
# [19:22:05] [300]	valid's binary_logloss: 0.00337015	valid's Opt metric: 0.57654
# [19:22:33] [400]	valid's binary_logloss: 0.00308056	valid's Opt metric: 0.551148
# [19:22:38] Early stopping, best iteration is:
# [319]	valid's binary_logloss: 0.00328232	valid's Opt metric: 0.602908
# [19:22:38] Trial 68 with hyperparameters {'feature_fraction': 0.5214335742979218, 'num_leaves': 210, 'bagging_fraction': 0.5992245773070223, 'min_sum_hessian_in_leaf': 0.32869214445489425} scored 0.6029079292377895 in 0:02:04.326946
# [19:22:46] Training until validation scores don't improve for 100 rounds
# [19:23:14] [100]	valid's binary_logloss: 0.00759423	valid's Opt metric: 0.486834
# [19:23:43] [200]	valid's binary_logloss: 0.00423242	valid's Opt metric: 0.505872
# [19:24:07] Early stopping, best iteration is:
# [185]	valid's binary_logloss: 0.00440708	valid's Opt metric: 0.519254
# [19:24:07] Trial 69 with hyperparameters {'feature_fraction': 0.5585694446689641, 'num_leaves': 206, 'bagging_fraction': 0.6010852659111415, 'min_sum_hessian_in_leaf': 0.29674941323303927} scored 0.5192536111467356 in 0:01:28.851533
# [19:24:15] Training until validation scores don't improve for 100 rounds
# [19:24:41] [100]	valid's binary_logloss: 0.00796659	valid's Opt metric: 0.450852
# [19:25:09] [200]	valid's binary_logloss: 0.00420306	valid's Opt metric: 0.59221
# [19:25:38] [300]	valid's binary_logloss: 0.0037051	valid's Opt metric: 0.60167
# [19:25:47] Early stopping, best iteration is:
# [234]	valid's binary_logloss: 0.00397877	valid's Opt metric: 0.664203
# [19:25:47] Trial 70 with hyperparameters {'feature_fraction': 0.5399752936842814, 'num_leaves': 214, 'bagging_fraction': 0.5161484629584793, 'min_sum_hessian_in_leaf': 0.5279758480700166} scored 0.6642029852182542 in 0:01:40.151266
# [19:25:55] Training until validation scores don't improve for 100 rounds
# [19:26:14] [100]	valid's binary_logloss: 0.00728114	valid's Opt metric: 0.459905
# [19:26:17] Early stopping, best iteration is:
# [16]	valid's binary_logloss: 0.0574696	valid's Opt metric: 0.575622
# [19:26:17] Trial 71 with hyperparameters {'feature_fraction': 0.6064636128263258, 'num_leaves': 214, 'bagging_fraction': 0.5132838435382298, 'min_sum_hessian_in_leaf': 0.07986036094063378} scored 0.5756223843411032 in 0:00:29.358459
# [19:26:25] Training until validation scores don't improve for 100 rounds
# [19:26:52] [100]	valid's binary_logloss: 0.00769851	valid's Opt metric: 0.345242
# [19:26:58] Early stopping, best iteration is:
# [22]	valid's binary_logloss: 0.0477996	valid's Opt metric: 0.503357
# [19:26:59] Trial 72 with hyperparameters {'feature_fraction': 0.5374647458564074, 'num_leaves': 249, 'bagging_fraction': 0.502398418477324, 'min_sum_hessian_in_leaf': 0.5479524164417526} scored 0.5033565544966981 in 0:00:41.653613
# [19:27:06] Training until validation scores don't improve for 100 rounds
# [19:27:34] [100]	valid's binary_logloss: 0.00766763	valid's Opt metric: 0.539201
# [19:28:03] [200]	valid's binary_logloss: 0.00391837	valid's Opt metric: 0.597571
# [19:28:32] [300]	valid's binary_logloss: 0.00335872	valid's Opt metric: 0.572748
# [19:28:44] Early stopping, best iteration is:
# [242]	valid's binary_logloss: 0.00359834	valid's Opt metric: 0.629132
# [19:28:45] Trial 73 with hyperparameters {'feature_fraction': 0.5152777456488656, 'num_leaves': 237, 'bagging_fraction': 0.5588938192970224, 'min_sum_hessian_in_leaf': 0.37799349717268954} scored 0.629132119107867 in 0:01:46.059925
# [19:28:53] Training until validation scores don't improve for 100 rounds
# [19:29:21] [100]	valid's binary_logloss: 0.00712369	valid's Opt metric: 0.458178
# [19:29:51] [200]	valid's binary_logloss: 0.00394426	valid's Opt metric: 0.5528
# [19:30:19] [300]	valid's binary_logloss: 0.00326854	valid's Opt metric: 0.581203
# [19:30:31] Early stopping, best iteration is:
# [238]	valid's binary_logloss: 0.0035476	valid's Opt metric: 0.609753
# [19:30:31] Trial 74 with hyperparameters {'feature_fraction': 0.5543932613164914, 'num_leaves': 235, 'bagging_fraction': 0.5234601700390645, 'min_sum_hessian_in_leaf': 0.3480099016163722} scored 0.6097529575131982 in 0:01:46.885957
# [19:30:39] Training until validation scores don't improve for 100 rounds
# [19:31:07] [100]	valid's binary_logloss: 0.00737843	valid's Opt metric: 0.429306
# [19:31:22] Early stopping, best iteration is:
# [51]	valid's binary_logloss: 0.019764	valid's Opt metric: 0.492648
# ...
# [03:02:57] [0]	valid-logloss:0.17902	valid-Opt_metric:0.10769
# [03:03:02] [100]	valid-logloss:0.03655	valid-Opt_metric:0.25631
# [03:03:03] [101]	valid-logloss:0.03599	valid-Opt_metric:0.25656
# [03:03:03] Trial 97 with hyperparameters {'colsample_bytree': 0.4, 'subsample': 0.6, 'max_depth': 11, 'learning_rate': 0.018, 'min_child_weight': 162, 'reg_alpha': 0.00914796594620527, 'reg_lambda': 0.01432661891244172} scored 0.25656511594533404 in 0:00:07.859146
# [03:03:05] [0]	valid-logloss:0.18039	valid-Opt_metric:0.18154
# [03:03:09] [100]	valid-logloss:0.06969	valid-Opt_metric:0.24492
# [03:03:10] [124]	valid-logloss:0.05671	valid-Opt_metric:0.26171
# [03:03:10] Trial 98 with hyperparameters {'colsample_bytree': 0.7, 'subsample': 0.8, 'max_depth': 7, 'learning_rate': 0.01, 'min_child_weight': 180, 'reg_alpha': 0.10458697456910274, 'reg_lambda': 0.03090719126113533} scored 0.2617069701170577 in 0:00:07.532187
# [03:03:12] [0]	valid-logloss:0.18008	valid-Opt_metric:0.17227
# [03:03:17] [100]	valid-logloss:0.05885	valid-Opt_metric:0.29776
# [03:03:18] [120]	valid-logloss:0.04796	valid-Opt_metric:0.30986
# [03:03:18] Trial 99 with hyperparameters {'colsample_bytree': 0.7, 'subsample': 0.8, 'max_depth': 7, 'learning_rate': 0.012, 'min_child_weight': 147, 'reg_alpha': 2.2409621703294293, 'reg_lambda': 0.04369505451359948} scored 0.30986151515405086 in 0:00:07.487228
# [03:03:20] [0]	valid-logloss:0.17923	valid-Opt_metric:0.13367
# [03:03:23] [100]	valid-logloss:0.04264	valid-Opt_metric:0.28325
# [03:03:24] [105]	valid-logloss:0.03990	valid-Opt_metric:0.28161
# [03:03:24] Trial 100 with hyperparameters {'colsample_bytree': 0.3, 'subsample': 0.4, 'max_depth': 5, 'learning_rate': 0.018, 'min_child_weight': 169, 'reg_alpha': 3.8728009626054565, 'reg_lambda': 0.004508837777881572} scored 0.2804090425068261 in 0:00:05.889285
# [03:03:24] Hyperparameters optimization for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost completed
# [03:03:24] The set of hyperparameters {'colsample_bytree': 0.7, 'subsample': 0.8, 'max_depth': 7, 'learning_rate': 0.018, 'min_child_weight': 149, 'reg_alpha': 0.017072187542230874, 'reg_lambda': 0.004330150414518719}
#  achieve 0.4446 AutoML Metric
# [03:03:24] Start fitting Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost ...
# [03:03:24] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:03:26] [0]	valid-logloss:0.17902	valid-Opt_metric:0.17225
# [03:03:31] [100]	valid-logloss:0.03540	valid-Opt_metric:0.38717
# [03:03:35] [200]	valid-logloss:0.01252	valid-Opt_metric:0.43106
# [03:03:40] [300]	valid-logloss:0.00783	valid-Opt_metric:0.46285
# [03:03:44] [400]	valid-logloss:0.00620	valid-Opt_metric:0.43816
# [03:03:46] [465]	valid-logloss:0.00561	valid-Opt_metric:0.44463
# [03:03:47] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:03:49] [0]	valid-logloss:0.35862	valid-Opt_metric:0.48363
# [03:03:53] [100]	valid-logloss:0.24219	valid-Opt_metric:0.56763
# [03:03:58] [200]	valid-logloss:0.22997	valid-Opt_metric:0.59154
# [03:04:02] [300]	valid-logloss:0.22700	valid-Opt_metric:0.60168
# [03:04:06] [400]	valid-logloss:0.22507	valid-Opt_metric:0.60960
# [03:04:10] [500]	valid-logloss:0.22332	valid-Opt_metric:0.61776
# [03:04:14] [600]	valid-logloss:0.22255	valid-Opt_metric:0.62185
# [03:04:17] [700]	valid-logloss:0.22222	valid-Opt_metric:0.62374
# [03:04:21] [800]	valid-logloss:0.22153	valid-Opt_metric:0.62740
# [03:04:25] [900]	valid-logloss:0.22104	valid-Opt_metric:0.62956
# [03:04:29] [1000]	valid-logloss:0.22055	valid-Opt_metric:0.63183
# [03:04:33] [1100]	valid-logloss:0.22010	valid-Opt_metric:0.63385
# [03:04:37] [1200]	valid-logloss:0.22002	valid-Opt_metric:0.63516
# [03:04:41] [1300]	valid-logloss:0.21977	valid-Opt_metric:0.63659
# [03:04:45] [1400]	valid-logloss:0.21954	valid-Opt_metric:0.63761
# [03:04:48] [1500]	valid-logloss:0.21977	valid-Opt_metric:0.63714
# [03:04:49] [1522]	valid-logloss:0.21971	valid-Opt_metric:0.63746
# [03:04:50] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:04:52] [0]	valid-logloss:0.36365	valid-Opt_metric:0.61151
# [03:04:57] [100]	valid-logloss:0.19241	valid-Opt_metric:0.81562
# [03:05:01] [200]	valid-logloss:0.17383	valid-Opt_metric:0.81817
# [03:05:05] [300]	valid-logloss:0.16622	valid-Opt_metric:0.82275
# [03:05:09] [400]	valid-logloss:0.16208	valid-Opt_metric:0.82553
# [03:05:13] [500]	valid-logloss:0.15950	valid-Opt_metric:0.82731
# [03:05:17] [600]	valid-logloss:0.15790	valid-Opt_metric:0.82853
# [03:05:21] [700]	valid-logloss:0.15576	valid-Opt_metric:0.83093
# [03:05:25] [800]	valid-logloss:0.15474	valid-Opt_metric:0.83132
# [03:05:29] [900]	valid-logloss:0.15389	valid-Opt_metric:0.83195
# [03:05:33] [1000]	valid-logloss:0.15266	valid-Opt_metric:0.83375
# [03:05:37] [1100]	valid-logloss:0.15191	valid-Opt_metric:0.83432
# [03:05:41] [1200]	valid-logloss:0.15142	valid-Opt_metric:0.83441
# [03:05:44] [1266]	valid-logloss:0.15147	valid-Opt_metric:0.83405
# [03:05:45] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:05:46] [0]	valid-logloss:0.29316	valid-Opt_metric:0.20197
# [03:05:51] [100]	valid-logloss:0.22087	valid-Opt_metric:0.31516
# [03:05:55] [200]	valid-logloss:0.21261	valid-Opt_metric:0.34996
# [03:05:59] [300]	valid-logloss:0.20952	valid-Opt_metric:0.37180
# [03:06:03] [400]	valid-logloss:0.20793	valid-Opt_metric:0.38631
# [03:06:07] [500]	valid-logloss:0.20647	valid-Opt_metric:0.39730
# [03:06:11] [600]	valid-logloss:0.20496	valid-Opt_metric:0.40458
# [03:06:15] [700]	valid-logloss:0.20328	valid-Opt_metric:0.41246
# [03:06:19] [800]	valid-logloss:0.20148	valid-Opt_metric:0.42041
# [03:06:23] [900]	valid-logloss:0.20033	valid-Opt_metric:0.42517
# [03:06:27] [1000]	valid-logloss:0.19961	valid-Opt_metric:0.42784
# [03:06:30] [1100]	valid-logloss:0.19942	valid-Opt_metric:0.42925
# [03:06:34] [1200]	valid-logloss:0.19865	valid-Opt_metric:0.43238
# [03:06:38] [1300]	valid-logloss:0.19792	valid-Opt_metric:0.43544
# [03:06:42] [1400]	valid-logloss:0.19755	valid-Opt_metric:0.43747
# [03:06:46] [1500]	valid-logloss:0.19742	valid-Opt_metric:0.43778
# [03:06:50] [1600]	valid-logloss:0.19711	valid-Opt_metric:0.43913
# [03:06:54] [1700]	valid-logloss:0.19654	valid-Opt_metric:0.44084
# [03:06:57] [1800]	valid-logloss:0.19616	valid-Opt_metric:0.44244
# [03:07:01] [1900]	valid-logloss:0.19611	valid-Opt_metric:0.44269
# [03:07:05] [2000]	valid-logloss:0.19577	valid-Opt_metric:0.44374
# [03:07:09] [2100]	valid-logloss:0.19578	valid-Opt_metric:0.44390
# [03:07:13] [2200]	valid-logloss:0.19545	valid-Opt_metric:0.44543
# [03:07:17] [2300]	valid-logloss:0.19543	valid-Opt_metric:0.44587
# [03:07:21] [2400]	valid-logloss:0.19544	valid-Opt_metric:0.44624
# [03:07:25] [2500]	valid-logloss:0.19514	valid-Opt_metric:0.44779
# [03:07:29] [2600]	valid-logloss:0.19500	valid-Opt_metric:0.44837
# [03:07:32] [2700]	valid-logloss:0.19482	valid-Opt_metric:0.44950
# [03:07:36] [2800]	valid-logloss:0.19461	valid-Opt_metric:0.45041
# [03:07:40] [2900]	valid-logloss:0.19464	valid-Opt_metric:0.45051
# [03:07:44] [2999]	valid-logloss:0.19455	valid-Opt_metric:0.45080
# [03:07:46] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:07:48] [0]	valid-logloss:0.30725	valid-Opt_metric:0.48804
# [03:07:52] [100]	valid-logloss:0.18731	valid-Opt_metric:0.59052
# [03:07:56] [173]	valid-logloss:0.17658	valid-Opt_metric:0.58860
# [03:07:56] ===== Start working with fold 5 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:07:58] [0]	valid-logloss:0.25317	valid-Opt_metric:0.27139
# [03:08:03] [100]	valid-logloss:0.14654	valid-Opt_metric:0.42312
# [03:08:07] [200]	valid-logloss:0.13338	valid-Opt_metric:0.41635
# [03:08:07] [201]	valid-logloss:0.13332	valid-Opt_metric:0.41627
# [03:08:08] ===== Start working with fold 6 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:08:10] [0]	valid-logloss:0.44608	valid-Opt_metric:0.44761
# [03:08:14] [100]	valid-logloss:0.38026	valid-Opt_metric:0.50505
# [03:08:19] [200]	valid-logloss:0.39003	valid-Opt_metric:0.50596
# [03:08:20] [231]	valid-logloss:0.39187	valid-Opt_metric:0.50583
# [03:08:21] ===== Start working with fold 7 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:08:22] [0]	valid-logloss:0.36206	valid-Opt_metric:0.53671
# [03:08:27] [100]	valid-logloss:0.22706	valid-Opt_metric:0.64598
# [03:08:31] [200]	valid-logloss:0.21345	valid-Opt_metric:0.65133
# [03:08:35] [300]	valid-logloss:0.21034	valid-Opt_metric:0.65857
# [03:08:39] [400]	valid-logloss:0.20856	valid-Opt_metric:0.66559
# [03:08:43] [500]	valid-logloss:0.20790	valid-Opt_metric:0.66754
# [03:08:47] [600]	valid-logloss:0.20707	valid-Opt_metric:0.67002
# [03:08:51] [700]	valid-logloss:0.20656	valid-Opt_metric:0.67167
# [03:08:54] [800]	valid-logloss:0.20578	valid-Opt_metric:0.67436
# [03:08:58] [900]	valid-logloss:0.20510	valid-Opt_metric:0.67648
# [03:09:02] [1000]	valid-logloss:0.20483	valid-Opt_metric:0.67732
# [03:09:06] [1100]	valid-logloss:0.20438	valid-Opt_metric:0.67876
# [03:09:10] [1200]	valid-logloss:0.20406	valid-Opt_metric:0.67946
# [03:09:14] [1300]	valid-logloss:0.20379	valid-Opt_metric:0.68018
# [03:09:18] [1400]	valid-logloss:0.20358	valid-Opt_metric:0.68077
# [03:09:21] [1500]	valid-logloss:0.20364	valid-Opt_metric:0.68082
# [03:09:24] [1560]	valid-logloss:0.20365	valid-Opt_metric:0.68089
# [03:09:25] ===== Start working with fold 8 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:09:27] [0]	valid-logloss:0.30130	valid-Opt_metric:0.37543
# [03:09:31] [100]	valid-logloss:0.19527	valid-Opt_metric:0.45658
# [03:09:36] [200]	valid-logloss:0.18183	valid-Opt_metric:0.47028
# [03:09:39] [300]	valid-logloss:0.17714	valid-Opt_metric:0.48126
# [03:09:43] [400]	valid-logloss:0.17457	valid-Opt_metric:0.49297
# [03:09:47] [500]	valid-logloss:0.17314	valid-Opt_metric:0.49900
# [03:09:51] [600]	valid-logloss:0.17139	valid-Opt_metric:0.50795
# [03:09:55] [700]	valid-logloss:0.17027	valid-Opt_metric:0.51453
# [03:09:59] [800]	valid-logloss:0.16958	valid-Opt_metric:0.51933
# [03:10:03] [900]	valid-logloss:0.16878	valid-Opt_metric:0.52388
# [03:10:07] [1000]	valid-logloss:0.16826	valid-Opt_metric:0.52731
# [03:10:11] [1100]	valid-logloss:0.16725	valid-Opt_metric:0.53358
# [03:10:14] [1200]	valid-logloss:0.16737	valid-Opt_metric:0.53198
# [03:10:15] [1219]	valid-logloss:0.16740	valid-Opt_metric:0.53183
# [03:10:16] ===== Start working with fold 9 for Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost =====
# [03:10:18] [0]	valid-logloss:0.27551	valid-Opt_metric:0.24686
# [03:10:22] [100]	valid-logloss:0.16926	valid-Opt_metric:0.49201
# [03:10:27] [200]	valid-logloss:0.15112	valid-Opt_metric:0.51435
# [03:10:31] [300]	valid-logloss:0.14471	valid-Opt_metric:0.53555
# [03:10:35] [400]	valid-logloss:0.14094	valid-Opt_metric:0.54875
# [03:10:39] [500]	valid-logloss:0.14005	valid-Opt_metric:0.54725
# [03:10:39] [506]	valid-logloss:0.14005	valid-Opt_metric:0.54693
# [03:10:39] Fitting Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost finished. score = 0.5990843735527028
# [03:10:39] Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost fitting and predicting completed
# [03:10:39] Time left 7501.40 secs
#
# [03:10:39] Layer 1 training completed.
#
# [03:10:40] Blending: optimization starts with equal weights. Score = 0.6067806
# [03:10:42] Blending: iteration 0: score = 0.6083265, weights = [0.11340741 0.13454188 0.31203267 0.         0.12430212 0.31571588]
# [03:10:44] Blending: iteration 1: score = 0.6084673, weights = [0.08862555 0.07583297 0.353102   0.         0.13912132 0.34331816]
# [03:10:46] Blending: iteration 2: score = 0.6084713, weights = [0.08419259 0.0811813  0.35344493 0.         0.14197838 0.3392028 ]
# [03:10:48] Blending: iteration 3: score = 0.6084724, weights = [0.07547413 0.08721487 0.35237834 0.         0.14395438 0.34097832]
# [03:10:51] Blending: iteration 4: score = 0.6084747, weights = [0.07789145 0.08013083 0.35436994 0.         0.14494924 0.3426586 ]
# [03:10:51] Blending: best score = 0.6084747, best weights = [0.07789145 0.08013083 0.35436994 0.         0.14494924 0.3426586 ]
# [03:10:51] Automl preset training completed in 4938.47 seconds
#
# [03:10:51] Model description:
# Final prediction for new objects (level 0) =
# 	 0.07789 * (10 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 	 0.08013 * (10 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM) +
# 	 0.35437 * (10 averaged models Lvl_0_Pipe_0_Mod_2_CatBoost) +
# 	 0.14495 * (10 averaged models Lvl_0_Pipe_0_Mod_4_XGBoost) +
# 	 0.34266 * (10 averaged models Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost)
#
# [03:10:51] ==================================================
# [03:10:51] Blending: optimization starts with equal weights. Score = 0.6122492
# [03:10:53] Blending: iteration 0: score = 0.6126275, weights = [0.1613822  0.08681055 0.48472285 0.26708445]
# [03:10:54] Blending: iteration 1: score = 0.6126672, weights = [0.21810263 0.10929042 0.45259872 0.22000822]
# [03:10:56] Blending: iteration 2: score = 0.6126675, weights = [0.2098494  0.1298148  0.44434142 0.21599434]
# [03:10:58] Blending: iteration 3: score = 0.6126685, weights = [0.19680981 0.13122119 0.4526471  0.21932194]
# [03:10:59] Blending: iteration 4: score = 0.6126687, weights = [0.20539324 0.13063188 0.4522899  0.21168497]
# [03:10:59] Blending: best score = 0.6126687, best weights = [0.20539324 0.13063188 0.4522899  0.21168497]
#
# category='Готовый бизнес и оборудование' oof_prauc=0.6126686800251008
# Final prediction for new objects =
# 	0.20539 * 1 averaged models with config = "conf_0_sel_type_0.yml" and different CV random_states. Their structures:
#
# 	    Model #0.
# 		================================================================================
# 		Final prediction for new objects (level 0) =
# 			 0.16434 * (10 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 			 0.35331 * (10 averaged models Lvl_0_Pipe_0_Mod_2_CatBoost) +
# 			 0.21550 * (10 averaged models Lvl_0_Pipe_0_Mod_4_XGBoost) +
# 			 0.26685 * (10 averaged models Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost)
# 		================================================================================
#
#
# 	+ 0.13063 * 1 averaged models with config = "conf_1_sel_type_1.yml" and different CV random_states. Their structures:
#
# 	    Model #0.
# 		================================================================================
# 		Final prediction for new objects (level 0) =
# 			 0.10415 * (10 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 			 0.15950 * (10 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM) +
# 			 0.06793 * (10 averaged models Lvl_0_Pipe_0_Mod_2_CatBoost) +
# 			 0.15348 * (10 averaged models Lvl_0_Pipe_0_Mod_3_Tuned_CatBoost) +
# 			 0.11601 * (10 averaged models Lvl_0_Pipe_0_Mod_4_XGBoost) +
# 			 0.39893 * (10 averaged models Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost)
# 		================================================================================
#
#
# 	+ 0.45229 * 1 averaged models with config = "conf_2_select_mode_1_no_typ.yml" and different CV random_states. Their structures:
#
# 	    Model #0.
# 		================================================================================
# 		Final prediction for new objects (level 0) =
# 			 0.06948 * (10 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 			 0.07896 * (10 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM) +
# 			 0.30233 * (10 averaged models Lvl_0_Pipe_0_Mod_2_CatBoost) +
# 			 0.08797 * (10 averaged models Lvl_0_Pipe_0_Mod_4_XGBoost) +
# 			 0.46127 * (10 averaged models Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost)
# 		================================================================================
#
#
# 	+ 0.21168 * 1 averaged models with config = "conf_3_sel_type_1_no_inter_lgbm.yml" and different CV random_states. Their structures:
#
# 	    Model #0.
# 		================================================================================
# 		Final prediction for new objects (level 0) =
# 			 0.07789 * (10 averaged models Lvl_0_Pipe_0_Mod_0_LightGBM) +
# 			 0.08013 * (10 averaged models Lvl_0_Pipe_0_Mod_1_Tuned_LightGBM) +
# 			 0.35437 * (10 averaged models Lvl_0_Pipe_0_Mod_2_CatBoost) +
# 			 0.14495 * (10 averaged models Lvl_0_Pipe_0_Mod_4_XGBoost) +
# 			 0.34266 * (10 averaged models Lvl_0_Pipe_0_Mod_5_Tuned_XGBoost)
# 		================================================================================
