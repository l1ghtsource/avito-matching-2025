# %%
import os
import pandas as pd

from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import precision_recall_curve, auc

from dataclasses import dataclass
from datasets import Dataset

import torch
import torch.nn as nn
import torch.nn.functional as F

from transformers import (
    AutoModelForSequenceClassification,
    AutoTokenizer,
    EvalPrediction,
    Trainer,
    TrainingArguments,
    DataCollatorWithPadding,
)
# Out:
# 2025-05-12 06:01:32.008160: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747029692.407369      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747029692.520067      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import numpy as np
import _codecs

torch.serialization.add_safe_globals([
    np.core.multiarray.scalar, 
    np.dtype, 
    np.dtypes.Float64DType, 
    np.dtypes.UInt32DType,
    np.core.multiarray._reconstruct,
    np.ndarray,
    _codecs.encode, 
])

# %%
VER = 1
N_FOLD = 0

os.environ['WANDB_PROJECT'] = f'fixed-clf-bert-fold{N_FOLD}'
os.environ['WANDB_NOTES'] = f'fixed-clf-bert-fold{N_FOLD}'
os.environ['WANDB_NAME'] = f'fixed-clf-bert-fold{N_FOLD}'

# %%
df = pd.read_parquet(
    'train_texts.parquet',
    columns=['variantid_1', 'variantid_2', 'group_id', 'is_double']
)

df = df.sort_values(by=['variantid_1', 'variantid_2'])
df = df.sample(len(df), random_state=42)

sgkf = StratifiedGroupKFold(n_splits=5)

fold_mapping = {
    '0': {
        'train_idxs': [],
        'val_idxs': [],
    },
    '1': {
        'train_idxs': [],
        'val_idxs': [],
    },
    '2': {
        'train_idxs': [],
        'val_idxs': [],
    },
    '3': {
        'train_idxs': [],
        'val_idxs': [],
    },
    '4': {
        'train_idxs': [],
        'val_idxs': [],
    },
}

for fold, (train_idx, val_idx) in enumerate(sgkf.split(df, df['is_double'], groups=df['group_id'])):
    fold_mapping[str(fold)]['train_idxs'] = train_idx
    fold_mapping[str(fold)]['val_idxs'] = val_idx

# %%
dataset = Dataset.from_parquet('avito-for-dl-train.parquet')
dataset = dataset.rename_column('is_double', 'label')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
train_dataset = dataset.select(fold_mapping[str(N_FOLD)]['train_idxs'].tolist())
eval_dataset = dataset.select(fold_mapping[str(N_FOLD)]['val_idxs'].tolist())

# %%
len(train_dataset), len(eval_dataset)
# Out:
# (1503646, 375909)

# %%
train_dataset[0]
# Out:
# {'variantid_1': 'cde98f598e17804a4346f1821f63bd7d8ab5eff0f7e501115eea3d3c7958b37c',
#  'variantid_2': 'fa310f51c7a25c96e0bd78c8e417fc79b806ee8a591d6330c4f9aeae71fd1fda',
#  'product_row': 'NAME1: Пресс гидравлический для склеивания бруса и щита; NAME2: Пресс для бруса и балок гидравлический\nCATEGORY1: Готовый бизнес и оборудование->Оборудование для бизнеса->Промышленное->Станки; CATEGORY2: Готовый бизнес и оборудование->Оборудование для бизнеса->Промышленное->Станки\nDESCRIPTION1: Пресс гидравлический модели SLН - GМ со съемными механическими фронтальными прижимами\n\nПресс вайма применяется на\xa0предприятиях и\xa0цехах по\xa0производству строительного и\xa0оконного бруса, столярно-строительных изделий, предприятиях по\xa0изготовлению деревянных конструкций, сборных домов, каркасного домостроения, элементов отделки и т. д.\n\nВайма гидравлическая равномерно распределяет усилие по\xa0плоскости прессования, обеспечивает высокое качество клеевого шва.\n\nГидравлические блоки снабжены системой устойчивости к\xa0высокому давлению и защитой от\xa0протекания.\n\nМеханические фронтальные прижимы удобно и\xa0быстро устанавливаются и\xa0зажимают пакет на\xa0необходимое усилие.\n\nГидростанция может быть оснащена одно- или много- секционным гидрораспределителем для раздельного управления, регулятор давления обеспечивает поддержание заданной величины.\n\nОсобенности модели:\n\n🔹параметры рабочей зоны: длина 3; 4; 4,5 или 6 м, высота - 1250 мм;\n\n🔹 наибольшая ширина пласти доски: 150 мм;\n\n🔹 усилие силовых гидроцилиндров ; DESCRIPTION2: Пресс гидравлический модели SLH - G с подъемными вверх гидравлическими фронтальными прижимами\n\nПресс вайма предназначена для склейки строительного и\xa0оконного бруса, стропильных конструкций, ламелей, балок. Вайма гидравлическая равномерно распределяет усилие по\xa0плоскости прессования, обеспечивает высокое качество клеевого шва.\n\nПрименяется на\xa0предприятиях и\xa0цехах по\xa0производству строительного и\xa0оконного бруса, столярно-строительных изделий, предприятиях по\xa0изготовлению деревянных конструкций, сборных домов, каркасного домостроения, элементов отделки и т. д.\n\nВ многопоточной гидростанции можно регулировать давление.\n\nВайма гидравлическая оснащена подъемными вверх гидравлическими фронтальными прижимами, что обеспечивает свободный доступ к\xa0рабочей зоне при укладке и\xa0выгрузке.\n\nГидравлические фронтальные прижимы гарантированно выравнивают и\xa0удерживают пакет заготовок во\xa0время прессования.\n\nВ\xa0пресс вайме модели SLH наклонная рама с\xa0задними упорами регулируются с\xa0шагом 10\xa0мм.\n\nРегулируемые за',
#  'group_id': 254861,
#  'label': 0,
#  '__index_level_0__': 1513586}

# %%
@dataclass
class Config:
    output_dir: str = 'output'
    checkpoint: str = 'DeepPavlov/rubert-base-cased'
    num_labels: int = 2
    max_length: int = 512
    optim_type: str = 'adamw_torch'
    per_device_train_batch_size: int = 32
    gradient_accumulation_steps: int = 1
    per_device_eval_batch_size: int = 32
    n_epochs: int = 1
    lr: float = 2e-5
    warmup_ratio: int = 0.03
    
config = Config()

# %%
training_args = TrainingArguments(
    output_dir=f'output-{VER}',
    overwrite_output_dir=True,
    report_to='wandb',
    num_train_epochs=config.n_epochs,
    per_device_train_batch_size=config.per_device_train_batch_size,
    gradient_accumulation_steps=config.gradient_accumulation_steps,
    # per_device_eval_batch_size=config.per_device_eval_batch_size,
    logging_steps=1,
    # eval_strategy='epoch',
    save_strategy='steps',
    save_steps=500,
    save_total_limit=4,
    optim=config.optim_type,
    learning_rate=config.lr,
    warmup_ratio=config.warmup_ratio,
    remove_unused_columns=False,
    lr_scheduler_type='cosine',  # 'cosine' or 'linear' or 'constant' (default is 'linear')
)

# %%
tokenizer = AutoTokenizer.from_pretrained(config.checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    config.checkpoint,
    num_labels=config.num_labels,
    device_map='cuda:0',
    trust_remote_code=True
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/714M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(df['is_double']),
    y=df['is_double']
)

# %%
def collate_fn(batch):
    texts = [item['product_row'] for item in batch]
    labels = torch.tensor([item['label'] for item in batch])
    
    result = tokenizer(
        texts, 
        padding=True, 
        truncation=True, 
        max_length=config.max_length,
        return_tensors="pt"
    )
    
    result["labels"] = labels
    
    return result

# %%
class WeightedCETrainer(Trainer):
    def __init__(self, *args, class_weights=None, **kwargs):
        super().__init__(*args, **kwargs)
        if class_weights is not None:
            self.class_weights = torch.tensor(class_weights, dtype=torch.float)

    def compute_loss(self, model, inputs, num_items_in_batch=None, return_outputs=False):
        labels = inputs.get('labels')
        outputs = model(**inputs)
        logits = outputs.get('logits')
        
        loss_fct = torch.nn.CrossEntropyLoss(weight=self.class_weights.to(self.model.device))
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

# %%
def compute_metrics(eval_preds: EvalPrediction) -> dict:
    y_true = eval_preds.label_ids
    y_pred = eval_preds.predictions[:, 1]
    
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    prauc = auc(recall, precision)

    return {
        'prauc': prauc
    }

# %%
import time
from transformers import TrainerCallback

class TimeLimitCallback(TrainerCallback):
    def __init__(self, time_limit_hours):
        self.time_limit_seconds = time_limit_hours * 3600
        self.start_time = None

    def on_train_begin(self, args, state, control, **kwargs):
        self.start_time = time.time()

    def on_step_end(self, args, state, control, **kwargs):
        elapsed_time = time.time() - self.start_time
        if elapsed_time >= self.time_limit_seconds:
            control.should_training_stop = True

# %%
trainer = WeightedCETrainer(
    args=training_args, 
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_dataset,
    # eval_dataset=eval_dataset,
    # compute_metrics=compute_metrics,
    data_collator=collate_fn,
    class_weights=class_weights,
    # callbacks=[TimeLimitCallback(time_limit_hours=11.5)]
)
# Out:
# /tmp/ipykernel_19/651345406.py:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `WeightedCETrainer.__init__`. Use `processing_class` instead.
#   super().__init__(*args, **kwargs)

# %%
trainer.train('rubert-folds0/output-1/checkpoint-23495')
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: lightsource- (lightsource-unk) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Tracking run with wandb version 0.19.6
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250512_060433-es4x9wwe
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run output-1
# wandb: ⭐️ View project at https://wandb.ai/lightsource-unk/fixed-clf-bert-fold2
# wandb: 🚀 View run at https://wandb.ai/lightsource-unk/fixed-clf-bert-fold2/runs/es4x9wwe
#     <div>
#
#       <progress value='23495' max='23495' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [23495/23495 : < :, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=23495, training_loss=0.0, metrics={'train_runtime': 3.9319, 'train_samples_per_second': 382424.091, 'train_steps_per_second': 5975.512, 'total_flos': 3.9562588594784256e+17, 'train_loss': 0.0, 'epoch': 1.0})

# %%
training_args.per_device_eval_batch_size = config.per_device_eval_batch_size
training_args.eval_strategy = 'epoch'
trainer.eval_dataset = eval_dataset
trainer.compute_metrics = compute_metrics

# %%
output = trainer.predict(test_dataset=eval_dataset)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:71: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(

# %%
predictions = output.predictions
metrics = output.metrics

# %%
import joblib

joblib.dump(predictions, 'predictions.joblib')
joblib.dump(metrics, 'metrics.joblib')
# Out:
# ['metrics.joblib']

# %%
# final_output_dir = f'{config.output_dir}/final_fold{N_FOLD}'
# model.save(final_output_dir)
